# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Netflix.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected trajectory of Average Revenue Per User (ARPU) across different geographic segments following the recent ad-tier rollout?
# 2. How much churn is expected to increase or decrease as a direct result of the crackdown on password sharing measures?
# 3. What is the anticipated impact of original content spend on the long-term lifetime value (LTV) of new subscribers?
# 4. To what extent is the content library diversifying into non-English language originals to capture emerging market growth?
# 5. What is the forecasted ratio of licensed content versus original productions in the upcoming two-year content budget cycle?
# 6. How will the expansion into mobile gaming influence subscriber retention rates and engagement metrics?
#
# **Industry & Competition**
# 7. How is the pricing power of Netflix evolving relative to Disney+, Max, and Amazon Prime Video in saturated markets?
# 8. What is the expected market share shift in the ad-supported streaming tier as competitors mature their advertising technologies?
# 9. To what degree will the consolidation of rival streaming services (e.g., mergers) impact Netflix’s customer acquisition costs (CAC)?
# 10. How does the competitive landscape for live sports broadcasting rights influence Netflix’s content strategy and premium pricing?
# 11. What is the projected impact of "bundling" strategies from telecommunications providers on Netflix’s standalone subscriber growth?
#
# **Financial Performance**
# 12. What are the forecasted free cash flow (FCF) margins following the stabilization of heavy content investment cycles?
# 13. How will the capital allocation strategy shift between debt repayment and aggressive content acquisition in the next 24 months?
# 14. What is the projected impact of foreign exchange (FX) volatility on net income given the high percentage of international revenue?
# 15. How much of the expected revenue growth is attributable to the advertising segment versus core subscription increases?
# 16. What are the anticipated operating margin improvements resulting from increased scale and content amortization efficiencies?
#
# **Growth Drivers**
# 17. What is the projected revenue contribution from the ad-supported tier by the end of the next fiscal year?
# 18. How much incremental subscriber growth is expected from the expansion into lower-ARPU emerging markets?
# 19. What is the forecasted impact of moving into live events (e.g., sports, comedy specials) on advertising inventory pricing?
# 20. To what extent will the integration of advanced recommendation algorithms drive higher engagement and lower churn?
#
# **Operational Risks**
# 21. How would a significant increase in the cost of premium licensed content from major studios affect operating margins?
# 22. What is the potential impact of regional regulatory changes regarding content censorship on Netflix’s international subscriber base?
# 23. How vulnerable is the current growth model to sudden shifts in consumer discretionary spending patterns?
#
# **Macroeconomic Factors**
# 24. How will sustained high interest rates impact the cost of financing large-scale content production cycles?
# 25. What is the expected correlation between global inflation rates and the renewal rates of premium subscription tiers?
#
# **Management & Strategy**
# 26. How will management’s pivot toward a dual-revenue model (ads + sub) change the long-term target operating margin?
# 27. What is the strategic rationale behind the current balance between localized content production and global blockbuster hits?
#
# **Valuation Drivers**
# 28. How will the market re-rate Netflix’s multiple if growth shifts from subscriber volume to ARPU expansion?
# 29. To what extent will the transition from a "growth-at-all-costs" to a "profitability-first" model influence the P/E multiple?
#
# **Upcoming Catalysts**
# 30. What specific guidance regarding advertising revenue scale will be provided in the next quarterly earnings call to trigger a re-valuation?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Amazon.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected trajectory of Amazon Web Services (AWS) revenue growth relative to the broader cloud infrastructure market over the next 24 months?
# 2. How do the current trends in third-party seller services margins compare to the long-term margin expansion targets for the North American segment?
# 3. To what extent is the mix of high-margin advertising revenue increasing as a percentage of total retail sales?
# 4. What is the anticipated impact of Prime membership retention rates on the lifetime value (LTV) of the consumer segment?
# 5. How much of the projected retail growth is expected to be driven by physical grocery expansion versus e-commerce penetration?
# 6. What is the expected contribution of digital services and subscription revenue to the overall diversification of the company's cash flows?
#
# **Industry & Competition**
# 7. How is the aggressive pricing strategy of discount retailers (e.g., Walmart, Temu) expected to impact Amazon’s market share in the non-prime consumer segment?
# 8. What is the projected competitive landscape for cloud computing services (Azure, Google Cloud) regarding the integration of generative AI capabilities?
# 9. How will the rise of social commerce platforms affect Amazon's conversion rates among younger demographics?
# 10. What is the anticipated impact of rising logistics costs across the third-party logistics (3PL) industry on Amazon's fulfillment margins?
# 11. How are regulatory shifts regarding antitrust and self-preferencing in digital marketplaces likely to alter Amazon's retail platform dynamics?
#
# **Financial Performance**
# 12. What are the forecasted capital expenditure (CapEx) requirements for AWS data center expansion over the next three fiscal years?
# 13. How is the operating margin in the North American segment expected to evolve as the fulfillment network reaches optimal density?
# 14. What is the projected free cash flow (FCF) yield trend given the current level of investments in AI and logistics automation?
# 15. To what degree will the increasing scale of the advertising business improve the overall consolidated operating margin?
# 16. What is the expected impact of inventory turnover improvements on the working capital cycle in the upcoming fiscal periods?
#
# **Growth Drivers**
# 17. What is the estimated market penetration ceiling for Amazon’s advertising services within the video streaming (Prime Video) ecosystem?
# 18. How much incremental revenue is expected to be generated by the integration of generative AI tools for third-party seller optimization?
# 19. What is the projected growth rate of the healthcare services segment as Amazon expands its pharmacy and telehealth footprint?
# 20. How will the scaling of the "Buy with Prime" service drive adoption and revenue in the external e-commerce market?
#
# **Operational Risks**
# 21. How would a sustained increase in labor costs and unionization efforts within the fulfillment network impact the cost-to-serve metrics?
# 22. What is the potential impact of supply chain disruptions in the semiconductor industry on the growth of Amazon’s proprietary hardware division?
# 23. To what extent do increasing cybersecurity threats to AWS infrastructure pose a risk to long-term enterprise client retention?
#
# **Macroeconomic Factors**
# 24. How will fluctuations in consumer discretionary spending, driven by interest rate volatility, affect the average order value (AOV) in the retail segment?
# 25. What is the projected sensitivity of Amazon’s logistics and shipping costs to global energy price volatility?
#
# **Management & Strategy**
# 26. How does the current capital allocation strategy prioritize AI infrastructure investment versus share repurchases or dividends?
# 27. What is the strategic roadmap for expanding Amazon’s presence in emerging international markets relative to domestic saturation?
#
# **Valuation Drivers**
# 28. How will the shift in revenue mix from retail to high-margin AWS and Advertising services affect the company’s forward EV/EBITDA multiple?
# 29. What is the expected impact of terminal growth rate assumptions on the discounted cash flow (DCF) valuation in a high-interest-rate environment?
#
# **Upcoming Catalysts**
# 30. How is the upcoming launch of new generative AI-driven features for AWS expected to influence enterprise contract renewals and new client acquisitions?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Amcor.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected trajectory of revenue growth within the healthcare packaging segment compared to the consumer packaging segment over the next 36 months?
# 2. How will the shift from rigid to flexible packaging architectures impact Amcor’s long-term gross margin profile?
# 3. What percentage of the current product portfolio is expected to be transitioned to circular or highly recyclable formats by 2030?
# 4. To what extent will the integration of recent specialty packaging acquisitions contribute to incremental EBITDA margins in the next fiscal year?
# 5. How does the current customer concentration risk evolve as Amcor pursues larger, multi-region contracts with global FMCG leaders?
# 6. What is the expected impact of the product mix shift toward high-barrier medical packaging on the company's overall return on invested capital (ROIC)?
#
# **Industry & Competition**
# 7. How is the intensifying competition from regional players in emerging markets expected to affect Amcor’s pricing power in Asia and Latin America?
# 8. What is the anticipated market share capture potential resulting from the industry-wide transition toward mono-material recyclable films?
# 9. How are competitors' investments in sustainable polymer technologies creating a gap in Amcor’s technological moat?
# 10. What is the projected impact of global plastic taxation and extended producer responsibility (EPR) legislation on total industry volume?
# 11. How will the consolidation of large-scale food and beverage converters affect Amcor's bargaining position with upstream resin suppliers?
#
# **Financial Performance**
# 12. What is the forecasted free cash flow conversion rate following the completion of the current cycle of capital expenditures?
# 13. How much margin expansion is anticipated from the ongoing cost-optimization and operational efficiency programs?
# 14. What is the expected trajectory of the net debt-to-EBITDA ratio as the company balances debt reduction with inorganic growth investments?
# 15. How will fluctuations in the spread between raw material costs (resins/paper) and finished goods selling prices affect quarterly earnings volatility?
# 16. What is the projected dividend growth rate supported by the company’s long-term earnings per share (EPS) guidance?
#
# **Growth Drivers**
# 17. What is the expected CAGR for revenue driven by the expansion of the pharmaceutical and medical device packaging segment?
# 18. How much volume growth is anticipated from the rising demand for e-commerce-optimized protective packaging?
# 19. To what degree will the expansion of capacity in high-growth emerging markets drive top-line acceleration over the next five years?
# 20. What is the projected revenue contribution from new, proprietary sustainable material innovations currently in the R&D pipeline?
#
# **Operational Risks**
# 21. How will volatility in the cost of recycled PET (rPET) and other sustainable feedstock affect the realization of sustainable premium pricing?
# 22. What is the potential impact of supply chain disruptions in key chemical precursor markets on production continuity?
# 23. How significant is the risk of capacity underutilization if global consumer spending slows down in the packaging-heavy CPG sector?
#
# **Macroeconomic Factors**
# 24. How will a sustained period of high interest rates impact the cost of financing future large-scale acquisitions and capital improvements?
# 25. What is the expected correlation between global GDP growth in emerging markets and Amcor's volume growth in those regions?
#
# **Management & Strategy**
# 26. How effective is management’s capital allocation strategy in balancing share repurchases with the pursuit of high-margin specialty packaging acquisitions?
# 27. What is the strategic rationale for current geographic rebalancing, and how quickly will these moves materialize into margin improvements?
#
# **Valuation Drivers**
# 28. How will a shift in investor sentiment toward ESG-compliant companies impact Amcor’s trading multiple relative to its historical average?
# 29. What level of organic volume growth is required to justify a premium valuation over peer-group multiples?
#
# **Upcoming Catalysts**
# 30. What are the specific anticipated impacts of the upcoming quarterly earnings report regarding updated full-year guidance for organic revenue growth?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_AmEx.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected trajectory of premium cardmember acquisition versus mass-market segment expansion over the next 24 months?
# 2. How is the evolving mix of charge card versus credit card usage expected to impact net interest margins?
# 3. To what extent will the current spend-per-cardmember trend continue to deviate from broader consumer discretionary spending patterns?
# 4. What is the anticipated impact of closed-loop network data on the pricing power of merchant discount rates?
# 5. How will the composition of the loan portfolio shift between consumer revolving credit and small business commercial lending in the coming fiscal years?
# 6. What are the projected changes in customer lifetime value (LTV) as a result of recent enhancements to premium travel and lifestyle benefits?
#
# **Industry & Competition**
# 7. How will the aggressive expansion of fintech competitors into the premium rewards space affect American Express's market share in the high-net-worth segment?
# 8. To what degree is the rising cost of customer acquisition impacting the competitive moat against traditional banking incumbents?
# 9. How will the integration of embedded finance solutions by tech giants influence the transaction volume of the American Express network?
# 10. What is the expected impact of interoperability shifts in payment networks on American Express’s closed-loop competitive advantage?
# 11. How do the reward program loyalty metrics of American Express compare to industry peers in terms of preventing churn during periods of high inflation?
#
# **Financial Performance**
# 12. What are the forecasted trends for credit loss provisions relative to the overall growth in the total receivables balance?
# 13. How will the projected volume of cross-border transactions influence the non-interest income revenue stream?
# 14. What is the expected margin impact of higher funding costs on the net interest income (NII) profile?
# 15. To what extent will the scaling of the small business segment contribute to the overall Return on Tangible Common Equity (ROTCE)?
# 16. How are changes in the credit card delinquency rates expected to correlate with the company's provision for credit losses in the next four quarters?
#
# **Growth Drivers**
# 17. What is the projected revenue contribution from the international expansion of the American Express network over the next three years?
# 18. How will the deepening of digital wallet integrations and contactless payment technologies drive incremental transaction volumes?
# 19. What is the expected impact of the current merchant acquiring strategy on the total take rate per transaction?
# 20. To what extent will the expansion of corporate travel programs offset potential softness in consumer discretionary spending?
#
# **Operational Risks**
# 21. How would a significant deterioration in the credit quality of the small business loan portfolio affect overall capital adequacy?
# 22. What is the potential impact of evolving data privacy regulations on the monetization of cardmember transaction data?
# 23. How vulnerable is the premium reward ecosystem to sudden shifts in consumer sentiment regarding luxury discretionary spending?
#
# **Macroeconomic Factors**
# 24. How will a sustained "higher-for-longer" interest rate environment affect the delta between interest income and interest expense?
# 25. What is the projected sensitivity of cardmember spending volumes to a potential contraction in real household disposable income?
#
# **Management & Strategy**
# 26. How will the current capital allocation strategy prioritize share repurchases versus organic investment in digital platform infrastructure?
# 27. What are the strategic implications of management’s focus on the "Millennial and Gen Z" demographic on long-term deposit and spend stability?
#
# **Valuation Drivers**
# 28. How will the projected evolution of the Price-to-Earnings (P/E) multiple reflect changes in the company's perceived risk profile regarding credit cycles?
# 29. What impact will shifts in the dividend payout ratio have on the total shareholder return (TSR) expectations of institutional investors?
#
# **Upcoming Catalysts**
# 30. What is the anticipated market reaction to the upcoming quarterly report regarding the guidance for net charge-off (NCO) rates?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Costco.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. To what extent is the membership renewal rate expected to deviate from current levels in the next four fiscal quarters?
# 2. What is the projected impact of the current product mix on the weighted average margin per square foot of warehouse space?
# 3. How will the planned expansion of private-label (Kirkland Signature) penetration affect overall gross margin profiles?
# 4. What is the forecasted rate of membership fee increases relative to historical inflationary trends?
# 5. How much incremental revenue is expected to be generated by the expansion of e-commerce fulfillment capabilities within existing warehouse footprints?
# 6. What is the projected impact of basket size changes on the per-member-per-year (PMBY) spending trend?
#
# **Industry & Competition**
# 7. How will the aggressive expansion of Sam’s Club’s digital ecosystem impact Costco’s market share in the suburban demographic?
# 8. To what degree will the entry of new discount retailers or big-box competitors affect Costco’s membership acquisition costs?
# 9. How do current consumer shifts toward "treasure hunt" shopping models favor Costco’s inventory turnover compared to traditional grocery retailers?
# 10. What is the expected impact of competitor loyalty programs on Costco’s member retention rates?
# 11. How will the rising cost of logistics and last-mile delivery in the warehouse club industry affect the competitive pricing advantage of Costco?
#
# **Financial Performance**
# 12. What is the forecasted trajectory of operating margin expansion resulting from economies of scale in global procurement?
# 13. How will the projected capital expenditure cycle for new warehouse openings affect free cash flow conversion in the near term?
# 14. To what degree will changes in inventory turnover ratios impact the company's working capital efficiency over the next 12 months?
# 15. What is the expected impact of interest rate fluctuations on the cost of debt servicing for future warehouse expansions?
# 16. How will the projected growth in membership fee revenue contribute to the bottom-line EPS growth rate?
#
# **Growth Drivers**
# 17. What is the anticipated revenue contribution from international warehouse openings in the next three fiscal years?
# 18. How will the expansion of high-margin categories, such as electronics and luxury goods, influence total sales growth?
# 19. What is the projected impact of increasing penetration in the e-commerce channel on the total revenue CAGR?
# 20. How much incremental growth is expected from the expansion of the "foodservice" and small-business customer segment?
#
# **Operational Risks**
# 21. How will potential labor shortages or rising minimum wage legislations in key operating regions impact SG&A expenses?
# 22. To what extent could supply chain disruptions in the global seafood or poultry categories impact gross margins?
# 23. What is the projected risk level of inventory shrinkage and theft based on current retail security trends?
#
# **Macroeconomic Factors**
# 24. How will sustained inflationary pressure on core food commodities affect the consumer's ability to maintain current shopping frequency?
# 25. What is the expected impact of a potential contraction in consumer discretionary spending on Costco’s non-grocery sales volume?
#
# **Management & Strategy**
# 26. How will the current executive succession planning impact the continuity of the company’s low-cost/high-volume strategic model?
# 27. To what degree will the company’s strategic pivot toward digital services and delivery alter its long-term capital allocation framework?
#
# **Valuation Drivers**
# 28. How will the projected growth in membership fee revenue impact the premium multiple applied to Costco’s P/E ratio?
# 29. What is the expected impact of the company’s share repurchase program on its long-term earnings per share (EPS) accretion?
#
# **Upcoming Catalysts**
# 30. How will the results of the upcoming annual membership fee adjustment cycle influence investor sentiment and short-term stock volatility?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Halliburton.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected mix of revenue between international and North American markets over the next 24 months?
# 2. To what extent is the company’s revenue concentration shifting toward high-margin completion and production services versus lower-margin drilling services?
# 3. How will the current capital expenditure cycles of major E&P (Exploration & Production) clients impact Halliburton's service volume forecasts?
# 4. What is the anticipated trajectory of the company's digital and automated drilling technology adoption rate among Tier 1 operators?
# 5. How will the transition toward unconventional reservoir development in emerging markets affect the company’s long-term service contract backlog?
# 6. What is the projected impact of the company's current asset lifecycle management on future maintenance and replacement CapEx requirements?
#
# **Industry & Competition**
# 7. How will the intensifying competition from specialized boutique service providers impact Halliburton’s market share in the hydraulic fracturing segment?
# 8. What is the expected impact of evolving environmental regulations regarding water management and chemical usage on the company's service offerings?
# 9. How are shifting drilling rig counts in the Permian Basin expected to correlate with Halliburton’s upcoming service revenue?
# 10. What is the projected impact of the industry-wide trend toward "integrated service models" on Halliburton's ability to win large-scale multi-year contracts?
# 11. How will the technological advancement of competitors in carbon capture and sequestration (CCS) services threaten or complement Halliburton's market position?
#
# **Financial Performance**
# 12. What are the projected free cash flow (FCF) margins assuming current commodity price volatility?
# 13. How will the company’s debt-to-EBITDA ratio evolve under various sustained oil price scenarios?
# 14. To what degree will improvements in supply chain efficiencies contribute to margin expansion in the next fiscal year?
# 15. What is the expected trajectory of Return on Invested Capital (ROIC) relative to the company’s current weighted average cost of capital (WACC)?
# 16. How will changes in working capital management, specifically days sales outstanding (DSO), impact the company’s liquidity position?
#
# **Growth Drivers**
# 17. What is the forecasted revenue contribution from the company's expansion into the Middle East and Latin American international markets?
# 18. How will the integration of recent technology acquisitions accelerate the company's entry into the energy transition services segment?
# 19. What is the expected growth rate of high-margin digital well-construction software subscriptions over the next three years?
# 20. How will increased global investment in deepwater offshore drilling influence the company's subsea service revenue?
#
# **Operational Risks**
# 21. How will potential labor shortages and rising specialized technician wages impact the company's operating margins?
# 22. What is the potential impact of geopolitical instability in key oil-producing regions on the company's international asset security and service delivery?
# 23. To what extent does the company’s reliance on specific regional supply chains create vulnerability to localized logistics disruptions?
#
# **Macroeconomic Factors**
# 24. How will a sustained change in global interest rates affect the capital budgeting decisions of Halliburton’s primary E&P customers?
# 25. What is the projected impact of USD strength or weakness on the company's translated earnings from its international operations?
#
# **Management & Strategy**
# 26. How will the management’s stated capital allocation priority between share repurchases and debt reduction influence the total shareholder return (TSR)?
# 27. To what extent does the current strategic pivot toward "low-carbon" services align with the company's long-term CapEx deployment?
#
# **Valuation Drivers**
# 28. How will shifts in the long-term Brent/WTI crude oil price outlook re-rate the company’s EV/EBITDA multiple?
# 29. What is the expected impact of changes in the company's dividend payout ratio on its attractiveness to institutional value investors?
#
# **Upcoming Catalysts**
# 30. How will the upcoming quarterly earnings report's guidance regarding North American completion volumes serve as a signal for near-term stock price movement?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Honeywell.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. To what extent is the shift toward automation and software-driven industrial solutions impacting the mix of recurring vs. transactional revenue?
# 2. How do the current backlog levels in the Aerospace segment compare to historical trends, and what is the projected conversion rate to revenue over the next four quarters?
# 3. What is the expected trajectory of margin expansion within the Building Technologies segment as more high-margin IoT and building management software is integrated?
# 4. How significant is the revenue concentration within the Energy and Sustainability Solutions segment relative to the total industrial portfolio?
# 5. What is the anticipated impact of the current product lifecycle on the replacement cycle demand for Honeywell’s industrial control systems?
# 6. How are the recent portfolio optimizations and divestitures affecting the overall stability and predictability of the company’s free cash flow?
#
# **Industry & Competition**
# 7. How is the rapid advancement of autonomous flight technologies influencing Honeywell’s competitive positioning in the avionics market?
# 8. What is the projected market share shift between Honeywell and its primary competitors in the Honeywell Aerospace segment due to new propulsion technologies?
# 9. How do rising global standards for decarbonization and building efficiency act as a tailwind for the company’s sustainable building technologies?
# 10. To what degree are competitors’ advancements in additive manufacturing (3D printing) threatening or complementing Honeywell’s industrial manufacturing footprint?
# 11. How is the increasing integration of AI in industrial automation affecting the competitive barrier to entry for Honeywell’s software-as-a-service (SaaS) offerings?
#
# **Financial Performance**
# 12. What are the projected year-over-year changes in operating margins driven by the current balance of organic growth versus inorganic acquisitions?
# 13. How much capital expenditure is expected to be allocated toward R&D for next-generation aerospace and defense technologies over the next three fiscal years?
# 14. What is the forecasted impact of interest rate fluctuations on the servicing costs of Honeywell’s existing long-term debt?
# 15. How do the current working capital management trends suggest future changes in the company’s ability to fund dividend increases and share repurchases?
# 16. What is the expected trajectory of Return on Invested Capital (ROIC) as the company completes its recent strategic pivot toward high-growth megatrends?
#
# **Growth Drivers**
# 17. What is the estimated revenue contribution from the development of Sustainable Aviation Fuel (SAF) related technologies over the next five years?
# 18. How much growth is expected to be driven by the transition from hardware-centric sales to subscription-based industrial software models?
# 19. To what extent will the global push for grid modernization and energy transition accelerate demand for Honeywell’s advanced materials and energy solutions?
# 20. What is the projected scale of revenue growth from the integration of quantum computing capabilities within the company’s high-performance computing segments?
#
# **Operational Risks**
# 21. How vulnerable is the global aerospace supply chain to tier-2 and tier-3 supplier disruptions, and how will this impact delivery timelines?
# 22. What is the potential impact of increasing cybersecurity threats on the reliability and adoption of Honeywell’s connected industrial ecosystems?
# 23. How do changes in international trade policies and tariffs specifically affect the cost structure of Honeywell’s global manufacturing hubs?
#
# **Macroeconomic Factors**
# 24. How will a potential slowdown in global commercial aircraft deliveries impact the long-term revenue outlook for the Aerospace division?
# 25. To what degree does the sensitivity of industrial production indices in key markets (US, EU, China) correlate with Honeywell’s quarterly revenue volatility?
#
# **Management & Strategy**
# 26. How effectively is management executing the "megatrend" strategy to reallocate capital from low-growth legacy businesses to high-growth sectors?
# 27. What is the anticipated success rate of the company’s M&A strategy in terms of achieving immediate accretion to adjusted earnings per share (EPS)?
#
# **Valuation Drivers**
# 28. How does Honeywell’s current EV/EBITDA multiple compare to the peer average of diversified industrial conglomerates, and what justifies a premium or discount?
# 29. What level of organic revenue growth is required to justify the current forward P/E multiple relative to historical averages?
#
# **Upcoming Catalysts**
# 30. What specific milestones in the certification of new aerospace technologies or major contract awards are expected to serve as volatility triggers in the next 12 months?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Microsoft.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected multi-year CAGR for Azure cloud revenue as enterprise workloads shift from on-premise to hybrid and multi-cloud environments?
# 2. To what extent will the integration of Copilot across the Microsoft 365 ecosystem drive incremental Average Revenue Per User (ARPU) in the Productivity and Business Processes segment?
# 3. How much contribution can the Gaming segment (Xbox) provide to total revenue growth following the integration of Activision Blizzard assets?
# 4. What is the expected trajectory of commercial vs. consumer demand for LinkedIn services over the next 24 months?
# 5. How will the transition from perpetual software licenses to subscription-based SaaS models impact long-term recurring revenue visibility?
# 6. What is the projected market share capture within the enterprise security software market as customers consolidate their cybersecurity stacks?
#
# **Industry & Competition**
# 7. How does Microsoft’s capital expenditure on AI infrastructure compare to AWS and Google Cloud in terms of scaling compute capacity per dollar spent?
# 8. What specific competitive advantages does the Microsoft software stack hold in preventing customer churn to specialized AI startups?
# 9. To what degree will the increasing commoditization of basic cloud computing services impact Microsoft’s operating margins in the Intelligent Cloud segment?
# 10. How will the competitive landscape of generative AI LLMs (Large Language Models) impact Microsoft's ability to maintain premium pricing for its AI-enhanced tools?
# 11. What is the potential impact of open-source AI developments on the market demand for proprietary Microsoft-driven AI solutions?
#
# **Financial Performance**
# 12. What are the projected margins for the Azure business as it moves from the initial heavy investment phase into a period of scale and operational efficiency?
# 13. How will the current level of capital expenditure on data centers affect free cash flow (FCF) conversion rates over the next three fiscal years?
# 14. What is the anticipated impact of share repurchase programs on diluted earnings per share (EPS) growth relative to net income growth?
# 15. How much of the projected revenue growth is expected to be driven by organic expansion versus inorganic acquisitions?
# 16. What are the forecasted implications of deferred revenue trends on the predictability of future quarterly top-line growth?
#
# **Growth Drivers**
# 17. What is the estimated total addressable market (TAM) expansion resulting from the deployment of AI agents in enterprise workflows?
# 18. How much revenue growth can be attributed to the integration of OpenAI’s models into the Azure OpenAI Service?
# 19. What role will edge computing and IoT integration play in driving growth within the Dynamics 365 and mixed reality sectors?
# 20. How will the expansion of the "Small and Medium Business" (SMB) segment in emerging markets contribute to non-US revenue growth?
#
# **Operational Risks**
# 21. What are the potential long-term margin implications of rising electricity costs and energy scarcity for global data center operations?
# 22. How would increased regulatory scrutiny regarding antitrust and ecosystem bundling impact the rollout of new integrated software products?
# 23. To what extent does the reliance on third-party hardware manufacturers (e.g., NVIDIA) for AI training pose a risk to Microsoft’s product roadmap execution?
#
# **Macroeconomic Factors**
# 24. How will a sustained high-interest-rate environment affect enterprise IT budget allocations and the timing of large-scale digital transformation projects?
# 25. What is the expected sensitivity of Microsoft's enterprise software demand to fluctuations in global GDP growth and corporate spending cycles?
#
# **Management & Strategy**
# 26. How effectively is management balancing the high capital intensity of AI development with the need to maintain high operating margins?
# 27. What is the strategic rationale behind the current allocation of capital between R&D for generative AI and dividend increases?
#
# **Valuation Drivers**
# 28. How much of the current valuation premium is justified by the projected terminal growth rate of the Azure cloud business?
# 29. What is the expected impact on the P/E multiple if AI-driven revenue growth begins to decelerate toward historical software norms?
#
# **Upcoming Catalysts**
# 30. What specific milestones in the rollout of autonomous AI agents within the Windows and Office ecosystems are expected to trigger a re-rating of the stock?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Solventum.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected revenue CAGR for the core medical specialty segments (e.g., Dental, Wound Care, Orthopedics) over the next three fiscal years?
# 2. How will the recent spin-off from 3M impact the company’s long-term gross margin profile and operating leverage?
# 3. What is the anticipated mix shift between high-margin consumable products and lower-margin capital equipment in the product portfolio?
# 4. To what extent will the current R&D pipeline contribute to new product revenue within the next 24 months?
# 5. What are the projected customer retention rates and contract renewal trends within the hospital and outpatient clinical segments?
# 6. How will the company’s geographic revenue concentration evolve as it expands its footprint in emerging healthcare markets?
#
# **Industry & Competition**
# 7. How will shifting reimbursement policies from CMS (Centers for Medicare & Medicaid Services) impact the pricing power of Solventum’s specialized medical products?
# 8. What is the expected market share trajectory relative to key competitors in the advanced wound management and dental specialty sectors?
# 9. How are evolving clinical guidelines for minimally invasive procedures expected to drive demand for Solventum's specific product categories?
# 10. To what degree will the consolidation of healthcare provider networks affect the company’s ability to negotiate long-term supply agreements?
# 11. What impact will the integration of digital health and data-driven clinical tools have on the competitive moat of the company’s physical medical devices?
#
# **Financial Performance**
# 12. What are the projected Free Cash Flow (FCF) conversion rates following the separation from 3M’s corporate structure?
# 13. How will the company’s debt-to-EBITDA leverage ratio evolve as it transitions from a subsidiary to an independent entity?
# 14. What is the anticipated trajectory of operating margins as the company realizes post-spin-off cost synergies?
# 15. How will the capital allocation framework prioritize share repurchases versus strategic M&A in the upcoming fiscal periods?
# 16. What is the expected impact of inventory management efficiencies on the company’s working capital cycle?
#
# **Growth Drivers**
# 17. What is the projected contribution of new product launches to top-line growth over the medium term?
# 18. How will the increasing prevalence of chronic conditions (e.g., diabetes, aging population needs) act as a tailwind for specific product lines?
# 19. What is the expected scale of revenue growth derived from expanding the digital health and connected medical device ecosystem?
# 20. To what extent will strategic acquisitions in niche medical specialties accelerate market penetration?
#
# **Operational Risks**
# 21. How sensitive is the company’s supply chain to potential disruptions in the sourcing of specialized medical-grade raw materials?
# 22. What is the potential impact of evolving FDA regulatory pathways on the time-to-market for upcoming high-growth products?
# 23. How do rising labor costs within the specialized manufacturing sector threaten the company’s long-term margin expansion goals?
#
# **Macroeconomic Factors**
# 24. How will fluctuations in foreign exchange rates affect the reported earnings of the company’s international business units?
# 25. To what degree will changes in global healthcare spending volatility influence the timing of large-scale hospital capital expenditure cycles?
#
# **Management & Strategy**
# 26. How does management intend to balance organic R&D investment with inorganic growth through M&A to achieve long-term EPS targets?
# 27. What specific metrics is management using to track the successful execution of the post-spin-off operational restructuring?
#
# **Valuation Drivers**
# 28. What multiple expansion or contraction is expected based on the company's transition from a diversified conglomerate component to a pure-play healthcare specialty company?
# 29. How will the projected Return on Invested Capital (ROIC) compare to the company’s Weighted Average Cost of Capital (WACC) in the next five years?
#
# **Upcoming Catalysts**
# 30. What specific clinical trial results or regulatory approvals are expected to serve as primary inflection points for the stock price in the next 12 months?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Ventas.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
f.close()
result = client.responses.create(
    model='gemma-4-26b-a4b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals**
# 1. What is the projected trajectory of the portfolio's occupancy rates across senior housing and healthcare segments over the next 24 months?
# 2. How will the mix of resident-pay versus government-funded (Medicaid/Medicare) tenants evolve in the current lease cycle?
# 3. What is the expected spread between the weighted average lease expiry (WALE) and the average life of the underlying debt?
# 4. To what extent will the current portfolio concentration in specific geographic Sunbelt markets impact revenue stability if regional demographics shift?
# 5. What are the projected maintenance CapEx requirements needed to sustain current Net Operating Income (NOI) levels across the aging asset base?
# 6. How will the company’s tenant credit quality profile change as existing long-term leases reach expiration in the next three fiscal years?
#
# **Industry & Competition**
# 7. How will the increasing supply of new purpose-built senior housing impact the pricing power of Ventas’s existing market share?
# 8. What is the projected impact of evolving state-level healthcare reimbursement policies on the solvency of Ventas's key operator tenants?
# 9. How do the current cap rates for senior housing real estate compare to the yields being offered by newly constructed competing facilities?
# 10. To what degree is the shift toward "aging-in-place" home healthcare models threatening the demand for traditional assisted living real estate?
# 11. How are specialized healthcare REIT competitors positioning their capital structures to aggressively outbid Ventas for prime medical office or senior living assets?
#
# **Financial Performance**
# 12. What is the forecasted growth rate of Funds From Operations (FFO) per share over the next eight quarters?
# 13. How will the company’s interest coverage ratio react to the upcoming refinancing ladder of its senior unsecured notes?
# 14. What is the projected impact of current inflation levels on the growth of contractual rent escalators versus operating expenses?
# 15. How will the planned dividend payout ratio evolve in relation to the projected free cash flow available for distribution?
# 16. What is the anticipated impact of any non-cash impairment charges on the total book value per share over the next two years?
#
# **Growth Drivers**
# 17. What is the projected internal rate of return (IRR) for the upcoming pipeline of acquisitions in the senior housing sector?
# 18. How much contribution to NOI is expected from the expansion of the medical office building (MOB) segment relative to senior housing?
# 19. To what extent can the implementation of more flexible, short-term lease structures drive higher top-line revenue during periods of high demand?
# 20. What is the expected scale of capital deployment into opportunistic healthcare real estate versus core stabilized assets over the next 18 months?
#
# **Operational Risks**
# 21. How will potential labor shortages and rising wage inflation among healthcare operators impact the ability of tenants to meet rent obligations?
# 22. What is the quantified risk of tenant default within the most significant third-party operator segment in the portfolio?
# 23. How would a significant increase in property insurance premiums affect the overall margin profile of the managed properties?
#
# **Macroeconomic Factors**
# 24. How will the projected path of the Federal Funds Rate influence the cost of new debt issuances for future portfolio expansion?
# 25. What is the sensitivity of the company’s Net Asset Value (NAV) to a 50-basis point shift in benchmark real estate cap rates?
#
# **Management & Strategy**
# 26. How does management’s current capital allocation framework prioritize debt reduction versus opportunistic acquisitions in the current high-rate environment?
# 27. What specific metrics is management using to evaluate the viability of entering new healthcare sub-sectors?
#
# **Valuation Drivers**
# 28. At what level of stabilized occupancy does the company's implied FFO multiple reach historical support levels?
# 29. How does the current premium or discount to NAV compare to the historical mean during similar interest rate cycles?
#
# **Upcoming Catalysts**
# 30. What specific impact will the upcoming quarterly earnings report have on the market's perception of the company's forward-looking guidance for same-store NOI growth?
