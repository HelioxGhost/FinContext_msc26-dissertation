# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Netflix.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How does Netflix project subscriber growth across its three tiers (Basic, Standard, Premium) over the next 12‑18 months, and what price‑elasticity assumptions underpin those forecasts?
# 2. What is the expected trajectory of contribution margin for Netflix’s domestic versus international streaming segments, and how will anticipated content‑cost efficiencies influence it?
# 3. How will Netflix allocate capital expenditures between original‑content production and technology infrastructure in the coming fiscal year, and what impact will that allocation have on cash‑flow generation?
# 4. How does Netflix anticipate churn to evolve with the introduction of its ad‑supported tier, and what net addition of paying subscribers does the company forecast after accounting for churn?
# 5. What average revenue per user (ARPU) growth rates does Netflix expect globally, and how do those rates differ by region and subscription plan through FY 2025?
# 6. How will upcoming changes to third‑party licensing agreements affect Netflix’s cost of goods sold and overall profitability over the next two years?
#
# **Industry & Competition (5)**
# 1. How does Netflix expect its global market‑share to shift relative to top competitors (e.g., Disney+, Amazon Prime Video, Apple TV+, HBO Max) under various content‑spending scenarios?
# 2. What is Netflix’s outlook for competitive pricing pressure in its core markets (U.S., Europe, India), and how will that pressure shape its future pricing strategy?
# 3. How will the rollout of 5G and improved broadband penetration in emerging markets affect Netflix’s subscriber‑acquisition cost and projected subscriber base?
# 4. What impact do bundled‑streaming offerings from telecom operators have on Netflix’s projected subscriber growth and pricing power?
# 5. How does Netflix plan to differentiate its recommendation algorithm and user experience to sustain engagement relative to rivals, and what measurable change in view‑time per subscriber is expected?
#
# **Financial Performance (5)**
# 1. What cash‑conversion‑cycle trends does Netflix forecast for the next three years, and how will changes in working‑capital components (e.g., subscription receivables, content amortization) affect free cash flow?
# 2. How does Netflix expect its effective tax rate to evolve with international profit repatriation and potential tax reforms, and what impact will that have on EPS?
# 3. What is the projected debt‑maturity profile and refinancing risk for Netflix, and how could shifts in interest rates influence its weighted‑average cost of capital?
# 4. How does Netflix forecast the ratio of content amortization to subscriber revenue, and what implications does that ratio have for future earnings guidance?
# 5. What impact do foreign‑exchange fluctuations have on Netflix’s reported revenue and margins in key non‑U.S. markets under different currency‑scenario assumptions?
#
# **Growth Drivers (4)**
# 1. How will the expansion of Netflix’s advertising‑supported tier reshape the overall revenue mix, and what incremental ad‑inventory growth does the company expect?
# 2. What contribution does Netflix anticipate from gaming and interactive content to total subscriber engagement and revenue over the next five years?
# 3. How will strategic partnerships with telecom carriers and smart‑TV manufacturers accelerate subscriber acquisition in under‑penetrated regions, and what subscriber targets are set for those alliances?
# 4. What revenue and margin uplift does Netflix project from localized original productions in high‑growth markets such as India, Brazil, and Southeast Asia?
#
# **Operational Risks (3)**
# 1. How does Netflix quantify the risk of cost overruns on large‑scale original productions, and what contingency measures are in place to protect profitability?
# 2. What is the anticipated impact of potential regulatory changes to streaming royalty rates or data‑privacy laws on Netflix’s operating costs and subscriber growth?
# 3. How vulnerable is Netflix’s content‑delivery network to geopolitical disruptions or cyber‑security incidents, and what financial impact could such events have on service continuity?
#
# **Macroeconomic Factors (2)**
# 1. How do projected global inflation trends and consumer‑discretionary‑spending forecasts affect Netflix’s subscriber‑acquisition and churn assumptions in both mature and emerging markets?
# 2. What is the sensitivity of Netflix’s projected cash flow to variations in key foreign‑exchange rates (e.g., USD/EUR, USD/INR) under different macro‑economic scenarios?
#
# **Management & Strategy (2)**
# 1. How does senior management evaluate the trade‑off between increasing content spend and maintaining cash‑flow discipline, and what thresholds trigger adjustments to the content budget?
# 2. What strategic milestones has management set for integrating AI‑driven personalization into the platform, and how are those milestones expected to influence subscriber retention and ARPU?
#
# **Valuation Drivers (2)**
# 1. What forward‑looking EBITDA or free‑cash‑flow multiple does management target for Netflix, and how does that target compare with current market multiples for peer streaming companies?
# 2. How does the expected return on invested capital (ROIC) from original‑content investments compare to Netflix’s cost of capital, and what implications does this have for intrinsic valuation?
#
# **Upcoming Catalysts (1)**
# 1. What are the key dates and anticipated market impact of upcoming flagship original series, major film premieres, and sports‑rights acquisitions on subscriber growth and revenue guidance?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Amazon.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How is Amazon’s mixed‑model retail strategy (e‑commerce, marketplace, and Amazon Fresh/Whole Foods) expected to reshape the revenue mix and profit contribution over the next 24 months?
# 2. What share of operating‑margin expansion is projected to come from AWS in FY 2025‑2027, given anticipated pricing, usage growth, and competitive positioning?
# 3. How will adjustments to Prime membership pricing and benefit tiers influence subscriber acquisition, churn, and incremental revenue through 2026?
# 4. In what ways is Amazon’s advertising platform expected to evolve to capture a larger portion of e‑commerce ad spend, and what revenue uplift is forecasted?
# 5. What effect will Amazon’s continued investments in fulfillment centers, delivery fleets, and last‑mile technology have on cost‑of‑goods‑sold and delivery cost per order by FY 2026?
# 6. How will the integration of physical retail assets (Whole Foods, Amazon Go) with Amazon’s digital ecosystem drive cross‑sell opportunities and same‑store sales growth?
#
# **Industry & Competition (5)**
# 1. How is Amazon positioning its marketplace fees and service suite to defend against emerging direct‑to‑consumer platforms (e.g., Shopify merchants), and what market‑share changes are expected?
# 2. What competitive pressures from Chinese e‑commerce giants in overseas markets could constrain Amazon’s international revenue growth, and how is the company responding?
# 3. How will rivals’ adoption of AI‑driven personalization affect Amazon’s conversion rates and average order value, and what counter‑measures are planned?
# 4. In what ways could pending antitrust investigations or other regulatory actions alter Amazon’s market access and competitive dynamics over the next three years?
# 5. How might the rise of buy‑now‑pay‑later financing among competitors impact Amazon’s financing costs, customer purchase behavior, and marketplace take‑rate?
#
# **Financial Performance (5)**
# 1. What free‑cash‑flow‑to‑EBITDA conversion rate does management expect for the next two fiscal years, considering planned capex and working‑capital trends?
# 2. How will the amortization of recent intangible‑asset acquisitions (e.g., MGM, Whole Foods) affect reported EPS and adjusted earnings guidance?
# 3. What trajectory is projected for Amazon’s effective tax rate in light of ongoing international tax reforms and potential R&D credits?
# 4. How does the evolving debt‑maturity profile influence interest expense, refinancing risk, and liquidity through 2027?
# 5. How sensitive is Amazon’s net‑income margin to freight‑cost inflation, and what scenarios are modeled for its impact on profitability?
#
# **Growth Drivers (4)**
# 1. What incremental revenue is expected from expanding subscription services (Prime Video, Music, Gaming) in high‑growth markets such as India and Brazil?
# 2. How will the rollout of generative‑AI tools within AWS (e.g., Bedrock) drive new customer acquisition and upsell revenue over the next 12‑18 months?
# 3. What sales lift is projected from extending same‑day delivery and drone‑logistics programs to additional international metros?
# 4. How will Amazon’s healthcare initiatives (Amazon Pharmacy, telehealth) contribute to top‑line growth and diversification of the revenue base?
#
# **Operational Risks (3)**
# 1. What cost and service‑disruption risks arise from Amazon’s reliance on third‑party logistics partners, and how could these affect order‑fulfillment metrics and margin?
# 2. How might supply‑chain constraints for high‑margin private‑label products impact gross‑margin trends in the coming years?
# 3. What cybersecurity and data‑privacy exposures could affect Amazon’s cloud and e‑commerce operations, and how are these reflected in the company’s risk disclosures?
#
# **Macroeconomic Factors (2)**
# 1. How is projected consumer‑discretionary‑spending elasticity expected to influence Amazon’s average order value and unit growth in recessionary scenarios?
# 2. What effect will anticipated changes in U.S. interest rates have on financing costs for Amazon’s capital‑intensive logistics projects and on valuation multiples?
#
# **Management & Strategy (2)**
# 1. How does senior management’s long‑term “customer‑obsession” vision translate into quantifiable investment priorities that could drive future earnings growth?
# 2. What is the board’s stance on allocating capital between share‑repurchases and reinvestment in growth initiatives, and how might this decision affect EPS dilution or accretion?
#
# **Valuation Drivers (2)**
# 1. How sensitive is a discounted‑cash‑flow valuation of Amazon to assumptions about AWS versus e‑commerce revenue growth, and what ranges are most plausible under current guidance?
# 2. What impact would a shift in the weighted‑average cost of capital—driven by macro‑policy changes—have on Amazon’s implied fair‑value multiple relative to peer companies?
#
# **Upcoming Catalysts (1)**
# 1. What financial and operational implications are anticipated from Amazon’s forthcoming Q4 earnings release and the planned launch of its next‑generation AI‑powered recommendation engine?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Amcor.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How does Amcor expect its product‑mix revenue allocation (e.g., flexible vs. rigid packaging, consumer goods vs. healthcare) to evolve over the next 24‑36 months, and what are the implied effects on gross margin?
# 2. What is the company’s forecasted “price‑to‑volume” growth trajectory for its core packaging businesses, and how does it compare with historical inflation‑adjusted volume trends?
# 3. Which specific cost‑saving initiatives (e.g., raw‑material sourcing, energy efficiency, automation) are projected to reduce SG&A expenses as a percentage of sales by FY2026?
# 4. How does Amcor anticipate the rollout of its circular‑economy solutions (recyclable, reusable, and compostable systems) to generate incremental revenue streams, and what timeline is provided for commercial scale?
# 5. What are the expected changes in the company’s working‑capital requirements (inventories, receivables, payables) as a function of projected sales growth and the shift toward longer‑term contracts?
# 6. How does Amcor project its effective tax rate to move over the next three years given recent M&A activity, repatriation of foreign earnings, and changes in global tax legislation?
#
# ---
#
# **Industry & Competition (5)**
# 7. What market‑share targets does Amcor set for its primary segments (e.g., flexible film, rigid containers) in the global packaging industry through 2027, and how does it plan to defend or expand against key competitors such as Berry Global and Sealed Air?
# 8. How will the anticipated acceleration of packaging‑regulation reforms (e.g., single‑use plastic bans, recycled‑content mandates) in North America, Europe, and Asia‑Pacific affect Amcor’s competitive positioning and pricing power?
# 9. What is the expected impact of emerging bio‑based material entrants on Amcor’s product pricing and margin assumptions over the next five years?
# 10. How does Amcor forecast the rate of adoption of digital packaging solutions (e.g., smart labels, IoT‑enabled tracking) across its customer base, and what share of revenue is expected to derive from these services by 2028?
# 11. In which geographic regions does Amcor anticipate the greatest competitive pressure from low‑cost producers, and what strategic actions (e.g., capacity relocation, joint ventures) are planned to mitigate margin erosion?
#
# ---
#
# **Financial Performance (5)**
# 12. What are Amcor’s projected earnings‑before‑interest‑tax‑depreciation‑amortization (EBITDA) growth rates for FY2024‑FY2027, and which line‑item drivers (e.g., volume, pricing, cost efficiencies) are most critical to achieving those rates?
# 13. How does the company expect its free‑cash‑flow conversion (free cash flow ÷ EBITDA) to evolve as a function of capital‑expenditure plans for new plant roll‑outs and sustainability projects?
# 14. What are the anticipated impacts of pending debt‑refinancing or covenant compliance tests on Amcor’s leverage ratios and interest‑coverage metrics through the next two fiscal years?
# 15. How does Amcor model the effect of foreign‑exchange fluctuations on its reported revenue and profit margins, given its exposure to Euro, Yen, and emerging‑market currencies?
# 16. What sensitivity assumptions does Amcor apply to its disclosed guidance regarding raw‑material price volatility (e.g., PET resin, aluminum), and how would a 10% increase in these inputs affect EPS forecasts?
#
# ---
#
# **Growth Drivers (4)**
# 17. What incremental volume growth does Amcor attribute to the expansion of its e‑commerce packaging solutions, and how is this quantified in its forward‑looking revenue guidance?
# 18. How does the company expect the rollout of its “Amcor Refresh” sustainability platform to attract new multinational consumer‑goods contracts, and what revenue contribution is targeted by 2029?
# 19. What are the projected earnings contributions from Amcor’s recent acquisitions (e.g., Bemis, Alpla assets) over the next three years, including expected synergies and integration timelines?
# 20. How does Amcor forecast demand growth for its medical‑device packaging segment, particularly in light of anticipated increases in global healthcare‑device shipments, and what margin profile is expected?
#
# ---
#
# **Operational Risks (3)**
# 21. What contingency plans does Amcor have for potential disruptions in key raw‑material supply chains (e.g., PET, aluminum) and how are expected cost impacts quantified in its risk‑adjusted financial models?
# 22. How does Amcor assess the risk of plant‑level operational downtime due to environmental regulations (e.g., emissions caps, water‑use restrictions) and what projected cost of compliance is included in its forward outlook?
# 23. What is the expected effect of labor‑force uncertainties (e.g., union negotiations, skill shortages) on Amcor’s operating efficiency metrics, and how are these incorporated into its earnings forecasts?
#
# ---
#
# **Macroeconomic Factors (2)**
# 24. How does Amcor incorporate projected global GDP growth differentials across its key markets into its demand‑forecast model for packaging volume and pricing power?
# 25. What impact does the expected trajectory of interest‑rate changes (e.g., Fed and ECB policy) have on Amcor’s cost of capital, weighted‑average cost of capital (WACC), and consequently its discounted cash‑flow valuation assumptions?
#
# ---
#
# **Management & Strategy (2)**
# 26. What strategic milestones does Amcor’s senior leadership outline for achieving its “net‑zero by 2050” climate goal, and how are associated capital allocations expected to affect long‑term profitability?
# 27. How does the board‑approved capital‑allocation framework prioritize returns between organic capacity expansion, acquisitions, and shareholder returns, and what guidance does management give on the expected return on invested capital (ROIC) for each category?
#
# ---
#
# **Valuation Drivers (2)**
# 28. What forward‑looking multiples (EV/EBITDA, P/E) does Amcor’s investor relations team target for the next 12‑18 months, and how are those multiples justified relative to peer benchmarking and projected growth rates?
# 29. How does Amcor expect changes in its dividend policy or share‑repurchase program to influence its implied equity cost and price‑to‑earnings multiple under a dividend‑discount or free‑cash‑flow model?
#
# ---
#
# **Upcoming Catalysts (1)**
# 30. What are the anticipated financial and strategic impacts of Amcor’s upcoming FY2025 earnings release, including any new sustainability‑linked financing arrangements or major contract wins expected to be disclosed?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_AmEx.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How is American Express forecasting the mix and growth rate of its consumer versus commercial cards over the next three years, and what revenue impact does it project for each segment?
# 2. What is the expected trajectory of American Express’s net transaction volume and average ticket size for its core network, and how does the company plan to capture additional share of high‑spending merchants?
# 3. How will the anticipated changes in the company’s fee structure (e.g., interchange, assessment, and service fees) affect its contribution margin in the upcoming fiscal periods?
# 4. What is American Express’s strategic outlook for its balance‑sheet composition, specifically the target levels of total assets, risk‑weighted assets, and liquidity ratios through 2028?
# 5. How does American Express expect its credit‑risk profile to evolve with the anticipated expansion into new credit products, and what forward‑looking credit‑loss provisions are planned?
# 6. What are the projected effects of the company’s digital‑payments initiatives (e.g., Amex Pay, API integration) on customer‑acquisition cost and lifetime‑value metrics over the next five years?
#
# **Industry & Competition (5)**
# 1. How does American Express anticipate its market share in the premium‑card segment to shift relative to Visa and Mastercard given the upcoming rollout of its new rewards architecture?
# 2. What are the expected impacts of emerging fintech platforms (e.g., Stripe, Square) on Amex’s merchant‑acceptance rates, and how is the company planning to mitigate potential dis‑intermediation?
# 3. In what ways will regulatory changes to interchange‑fee caps in key jurisdictions (e.g., EU, Australia) influence Amex’s competitive positioning and pricing strategy?
# 4. How does the projected growth of “buy‑now‑pay‑later” (BNPL) services affect Amex’s planned product extensions, and what market‑share targets does management set for BNPL‑linked card offerings?
# 5. What is the anticipated effect of consolidation among global payment processors on Amex’s partnership network, and how is the company positioning itself to capture cross‑border transaction volume?
#
# **Financial Performance (5)**
# 1. What earnings‑per‑share (EPS) growth rate does American Express target for the next three fiscal years, and what key drivers (e.g., net interest income, fee income) are embedded in that guidance?
# 2. How does the company forecast the composition and growth of its net interest margin, particularly in relation to the projected trajectory of the Federal Funds rate and loan‑portfolio mix?
# 3. What is the expected free‑cash‑flow conversion ratio over the next 12‑24 months, and how will that influence dividend policy and share‑repurchase plans?
# 4. How does Amex anticipate changes in its cost structure (e.g., technology spend, marketing expense) to affect operating leverage and ROIC in the medium term?
# 5. What forward‑looking assumptions underpin American Express’s provision for credit losses, and how sensitive is EPS to deviations from those assumptions?
#
# **Growth Drivers (4)**
# 1. How will the launch of the next‑generation Amex platform (e.g., AI‑driven personalization, real‑time analytics) be expected to lift average spend per active cardmember over the next five years?
# 2. What growth rates does the company project for its small‑business and mid‑market commercial card portfolios, and what initiatives are expected to drive that expansion?
# 3. How does American Express expect its partnership ecosystem (e.g., airline alliances, luxury retailers) to contribute incremental transaction volume and fee revenue in the upcoming fiscal periods?
# 4. What revenue uplift does Amex forecast from its expanding suite of data‑analytics services to merchants, and how will pricing models evolve to capture higher margin?
#
# **Operational Risks (3)**
# 1. What are the projected impacts of potential cyber‑security incidents on Amex’s transaction‑processing costs and customer attrition, and how does the company quantify those risks in its risk‑adjusted return models?
# 2. How does American Express assess the operational risk of scaling its card‑issuing platform in emerging markets, particularly regarding compliance, fraud, and settlement infrastructure?
# 3. What contingency plans does the firm have for disruptions in its global network connectivity (e.g., payment‑gateway failures), and how would such events affect short‑term revenue realization?
#
# **Macroeconomic Factors (2)**
# 1. How does American Express model the sensitivity of its fee and interest income to anticipated changes in consumer discretionary‑spending patterns under various GDP‑growth scenarios?
# 2. What macro‑level stress tests does Amex perform on its credit portfolio in relation to projected unemployment‑rate fluctuations, and how could those outcomes translate into earnings volatility?
#
# **Management & Strategy (2)**
# 1. How does the senior‑management team articulate its long‑term strategic objective for expanding the “unbanked” and under‑served segments, and what quantitative targets have been set for market penetration?
# 2. What governance mechanisms are in place to align executive compensation with the company’s stock‑price performance targets, and how might those mechanisms influence strategic decision‑making?
#
# **Valuation Drivers (2)**
# 1. Which forward‑looking multiples (e.g., EV/EBITDA, price/earnings) does American Express expect to compress or expand based on its projected earnings trajectory and industry dynamics, and what assumptions drive those expectations?
# 2. How does the company’s projected increase in share‑repurchase activity affect its diluted EPS and price‑to‑book ratio over the next two years?
#
# **Upcoming Catalysts (1)**
# 1. What specific milestones associated with the upcoming launch of American Express’s new global loyalty platform are expected to occur within the next 12 months, and how are those milestones likely to influence shareholder value?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Costco.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How does Costco project its membership renewal rate over the next 3‑5 years, and what pricing or benefit changes could impact that rate?
# 2. What assumptions is Costco making about average basket size growth per member in key markets, and how are those assumptions tied to product‑mix shifts?
# 3. In which geographic regions does Costco expect to open new warehouses, and what projected sales per square foot are being used for those locations?
# 4. How is Costco planning to allocate capital between store expansion, e‑commerce platforms, and technology upgrades, and what expected ROI does management assign to each category?
# 5. What are the anticipated changes in Costco’s private‑label (Kirkland) margin contribution, and how will new product categories affect overall gross profit?
# 6. How does Costco expect its operating leverage to evolve as a function of fixed‑cost absorption with the planned increase in store count?
#
# **Industry & Competition (5)**
# 1. How does Costco anticipate competitive pressure from Amazon’s grocery and membership services to affect its market share in the warehouse‑club segment over the next five years?
# 2. What is Costco’s outlook on price competition with Walmart’s Sam’s Club regarding price‑matching policies, and how might that affect its gross‑margin trajectory?
# 3. How will the evolution of omnichannel retail (e.g., curb‑side pickup, same‑day delivery) by peers influence Costco’s expected same‑store sales growth?
# 4. In which product categories does Costco expect to gain share from traditional grocery chains, and what promotional or assortment strategies are planned to capture that share?
# 5. How does Costco view regulatory changes in the U.S. and abroad (e.g., import tariffs, labeling rules) that could alter the competitive dynamics for its low‑price model?
#
# **Financial Performance (5)**
# 1. What are Costco’s projected cash‑conversion‑cycle trends, and how will changes in inventory turnover affect free‑cash‑flow generation?
# 2. How does management forecast the impact of rising labor costs on operating expenses, and what cost‑containment initiatives are expected to mitigate those effects?
# 3. What assumptions underlie Costco’s guidance for earnings‑per‑share growth, and how sensitive are those assumptions to changes in commodity‑price inflation?
# 4. How will the anticipated capital expenditures for new store openings and technology investments influence depreciation expense and net income over the next three years?
# 5. What is Costco’s expected debt‑maturity profile, and how might refinancing needs affect leverage ratios and cost of capital?
#
# **Growth Drivers (4)**
# 1. Which new product categories or services (e.g., health‑care, automotive, digital subscriptions) does Costco project will generate incremental revenue, and what forecasted contribution margins are assigned to them?
# 2. How does Costco expect international expansion, particularly in Asia‑Pacific, to impact overall revenue growth, and what market‑specific risks are factored into those projections?
# 3. What is the projected impact of expanding Costco’s online grocery platform on member acquisition and same‑store‑sales lift?
# 4. How will anticipated changes in consumer discretionary‑spending patterns, driven by demographics, influence Costco’s long‑term membership growth and sales‑per‑member?
#
# **Operational Risks (3)**
# 1. What supply‑chain disruption scenarios (e.g., port congestion, freight‑rate spikes) does Costco model, and how could those affect inventory availability and margin outlook?
# 2. How is Costco preparing for potential cybersecurity incidents affecting its e‑commerce and payment systems, and what financial impact does management estimate for a material breach?
# 3. What contingencies does Costco have for labor shortages in distribution centers and stores, and how might those contingencies affect operational efficiency and cost structure?
#
# **Macroeconomic Factors (2)**
# 1. How does Costco’s financial model incorporate projected inflation trends for food and non‑food items, and what are the expected effects on price elasticity and sales volume?
# 2. In what ways could changes in consumer confidence and disposable‑income levels across the U.S. and key international markets alter Costco’s membership renewal and same‑store‑sales forecasts?
#
# **Management & Strategy (2)**
# 1. What strategic initiatives is Costco undertaking to enhance its private‑label brand positioning, and how are those initiatives expected to influence market share and pricing power?
# 2. How does the executive team evaluate the trade‑off between aggressive store‑count expansion versus deepening existing‑store sales per square foot, and what targets have been set for each approach?
#
# **Valuation Drivers (2)**
# 1. Which multiples (e.g., EV/EBITDA, price‑to‑earnings) does management consider most reflective of Costco’s sustainable earnings power, and how are those multiples expected to evolve with earnings growth?
# 2. How does Costco’s projected free‑cash‑flow generation align with its share‑repurchase program, and what impact on intrinsic value per share is anticipated?
#
# **Upcoming Catalysts (1)**
# 1. What upcoming regulatory or market events (e.g., opening of a flagship store in a high‑growth metro, launch of a new membership tier, or a significant partnership) are expected to materially influence Costco’s stock price within the next 12 months?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Halliburton.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. What is the projected 12‑month backlog of drilling and well‑service contracts, and how does it compare with the current backlog level?
# 2. How does Halliburton anticipate changes in its service mix (drilling, completions, production) to affect average revenue per barrel over the next fiscal year?
# 3. What utilization‑rate assumptions are applied to Halliburton’s drilling rigs and completions equipment for the upcoming 24‑month horizon?
# 4. How will expected shifts in pricing for hydraulic‑fracturing fluids and chemically enhanced‑recovery services impact gross‑margin forecasts?
# 5. What impact does Halliburton expect from the anticipated capital‑expenditure cycles of major U.S. shale operators on its contract‑win rate in 2025‑2026?
# 6. How does the company plan to allocate its R&D budget toward digital‑oilfield solutions, and what incremental revenue contribution is targeted from those initiatives within three years?
#
# **Industry & Competition (5)**
# 1. How is Halliburton’s competitive positioning expected to evolve relative to Schlumberger and Baker Hughes in the emerging offshore‑wind‑energy service market?
# 2. What market‑share growth does Halliburton target in the U.S. shale‑completion segment over the next five years, and what pricing assumptions support that target?
# 3. How will potential consolidation among upstream operators affect Halliburton’s bargaining power and contract pricing in the Permian Basin?
# 4. What projected impact will new entrants offering AI‑driven well‑optimization platforms have on Halliburton’s service pricing and win rates?
# 5. How does the anticipated regulatory environment for methane‑emission reductions influence Halliburton’s competitive advantage in low‑carbon service offerings?
#
# **Financial Performance (5)**
# 1. What is Halliburton’s forecasted adjusted EBITDA‑margin trajectory for the next three fiscal years, and which cost‑control initiatives underpin that trajectory?
# 2. How does the company expect changes in its capital structure (debt repayments, share‑repurchase program) to affect diluted EPS and free‑cash‑flow generation?
# 3. What tax‑rate assumptions (domestic and international) are incorporated into Halliburton’s net‑income forecasts?
# 4. How will anticipated variations in foreign‑exchange rates (e.g., USD/EUR, USD/JPY) affect reported revenue and operating income in the next reporting period?
# 5. What magnitude of cash‑flow from operations relative to capital expenditures does Halliburton project for the upcoming 12‑month period, and how does this influence dividend sustainability?
#
# **Growth Drivers (4)**
# 1. What projected revenue contribution does Halliburton attribute to its carbon‑capture and sequestration services by 2028?
# 2. How does Halliburton estimate incremental demand for its digital well‑performance analytics platform over the next two years, and which pricing model will support that demand?
# 3. What growth rate does Halliburton forecast for its international (non‑U.S.) service contracts, and which geographic regions are expected to drive the majority of that growth?
# 4. How will anticipated adoption of extended‑reach drilling technologies influence equipment utilization and revenue per foot drilled?
#
# **Operational Risks (3)**
# 1. What are the projected impacts of potential supply‑chain disruptions for critical drilling components on project timelines and cost overruns in the next 12 months?
# 2. How does Halliburton assess the likelihood and financial effect of major health‑, safety‑, and environmental incidents on insurance premiums and contingency reserves?
# 3. What contingencies does Halliburton have in place to mitigate operational downtime caused by cybersecurity threats to its digital field platforms?
#
# **Macroeconomic Factors (2)**
# 1. How does Halliburton model the sensitivity of its revenue to oil‑price fluctuations, and what price range is incorporated in its baseline forecast for the next fiscal year?
# 2. What macro‑level assumptions regarding global energy‑demand growth are used to project the overall size of the oilfield‑services market through 2027?
#
# **Management & Strategy (2)**
# 1. How does senior management’s strategic plan for expanding into renewable‑energy infrastructure services translate into specific capital‑allocation targets over the next five years?
# 2. What performance metrics and incentive‑structure revisions are being implemented to align executive compensation with long‑term shareholder return, and how might those changes affect strategic decision‑making?
#
# **Valuation Drivers (2)**
# 1. What discount‑rate and terminal‑growth assumptions does Halliburton employ in its internal DCF model, and how are those inputs justified given current industry risk premiums?
# 2. How does Halliburton expect its forward P/E and EV/EBITDA multiples to evolve relative to peers under its projected earnings growth and capital‑return plan?
#
# **Upcoming Catalysts (1)**
# 1. What specific milestones related to the launch of Halliburton’s next‑generation frac‑sand delivery system are expected within the next six months, and how could those milestones influence the stock price?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Honeywell.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. What is the projected revenue growth rate for each of Honeywell’s four operating segments (Aerospace, Building Technologies, Performance Materials & Technologies, Safety & Productivity Solutions) over the next 24‑36 months, and how does management justify the assumptions behind those forecasts?
# 2. How does Honeywell expect its gross‑margin trajectory to evolve across its segments in the face of raw‑material cost volatility and supply‑chain constraints, and what specific initiatives are being implemented to protect margins?
# 3. What is the anticipated free‑cash‑flow conversion rate for Honeywell in the upcoming fiscal year, and how does management plan to prioritize reinvestment versus shareholder returns?
# 4. How will Honeywell’s capital‑expenditure program be weighted between maintenance, growth, and digital/technology investments through 2027, and what return‑on‑invested‑capital targets are set for each category?
# 5. What assumptions does Honeywell make regarding the renewal rate and pricing uplift of its long‑term service contracts across its aerospace and industrial businesses, and how sensitive are those assumptions to macro‑economic conditions?
# 6. How does Honeywell forecast the impact of its sustainability initiatives (e.g., energy‑efficient products, carbon‑reduction services) on revenue mix and margin contribution by 2028?
#
# **Industry & Competition (5)**
# 1. What market‑share trajectory does Honeywell expect in the commercial aerospace aftermarket versus its primary competitors, and what specific product or service innovations are driving that outlook?
# 2. How does Honeywell project competitive dynamics and pricing trends within the building‑automation and control‑systems market as IoT adoption accelerates, and what share‑gain strategies are outlined?
# 3. In the Performance Materials segment, how does Honeywell anticipate shifts in demand for specialty chemicals driven by electric‑vehicle battery production, and how does its competitive positioning compare with peers?
# 4. What are the expected effects of new entrants or consolidation in the Safety & Productivity Solutions market on Honeywell’s pricing power and contract‑win rates over the next three years?
# 5. How does Honeywell evaluate the risk of technology displacement (e.g., additive manufacturing, AI‑driven predictive maintenance) on its traditional product lines, and what mitigation plans are disclosed?
#
# **Financial Performance (5)**
# 1. What are Honeywell’s projected earnings‑per‑share (EPS) growth rates for FY2025‑FY2027 under the base case, and which line‑item drivers (operating income, tax rate, share count, etc.) are most influential?
# 2. How does management expect the debt‑maturity profile and cost of capital to evolve through 2028, and what refinancing strategies are being considered to maintain financial flexibility?
# 3. What is the anticipated trajectory of Honeywell’s effective tax rate over the next five years, including the impact of expected international tax reforms or repatriation strategies?
# 4. How will changes in working‑capital management (inventory turnover, accounts‑receivable days) affect Honeywell’s cash‑conversion cycle in the forward outlook?
# 5. What forward‑looking guidance does Honeywell provide on share‑repurchase program size and timing, and how might that influence diluted EPS and overall shareholder‑return expectations?
#
# **Growth Drivers (4)**
# 1. What revenue contribution does Honeywell forecast from its emerging quantum‑computing and advanced‑sensors business by 2028, and what milestones are tied to that growth?
# 2. How does Honeywell expect demand for its hydrogen‑compatible technologies and solutions to evolve as the global hydrogen economy scales, and what pipeline projects are currently under negotiation?
# 3. What are the projected incremental sales from digital‑transformation services (e.g., cloud‑based operations management) across Honeywell’s industrial customers, and how are pricing models structured?
# 4. How does Honeywell anticipate growth from geographic expansion, particularly in high‑growth markets such as India and Southeast Asia, and what market‑entry investments are planned?
#
# **Operational Risks (3)**
# 1. What supply‑chain risk assessments does Honeywell present for critical raw materials (e.g., rare‑earths, specialty gases), and how are contingency inventory levels modeled in its forward forecasts?
# 2. How does Honeywell quantify the potential earnings impact of cyber‑security breaches on its connected‑product ecosystem, and what mitigation investments are budgeted?
# 3. What operational contingencies are outlined for potential disruptions in aerospace production (e.g., labor strikes, regulatory‑certification delays), and how are they incorporated into the forecast variance analysis?
#
# **Macroeconomic Factors (2)**
# 1. How does Honeywell model the sensitivity of its revenue and margin outlook to projected changes in global industrial‑production indices and capital‑expenditure cycles over the next five years?
# 2. What assumptions does Honeywell make regarding inflation trends, interest‑rate movements, and foreign‑exchange fluctuations, and how are these macro variables expected to affect its cost structure and pricing strategy?
#
# **Management & Strategy (2)**
# 1. How does management’s stated “Invest‑to‑Grow” strategic roadmap translate into measurable targets for segment revenue mix, operating leverage, and ESG performance through 2027?
# 2. What succession‑planning and leadership‑development initiatives are disclosed that could influence strategic continuity and execution risk for Honeywell’s key growth initiatives?
#
# **Valuation Drivers (2)**
# 1. What forward‑looking valuation multiples (e.g., EV/EBITDA, P/E) does management anticipate the market will apply to Honeywell based on its projected cash‑flow generation and growth trajectory?
# 2. How does Honeywell’s internal discounted‑cash‑flow model incorporate assumptions about terminal growth rate, weighted‑average cost of capital, and capital‑expenditure intensity, and what sensitivity ranges are presented?
#
# **Upcoming Catalysts (1)**
# 1. What are the expected financial and strategic impacts of the upcoming acquisition slated for Q4 2026, including anticipated synergies, integration costs, and contribution to earnings guidance?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Microsoft.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How does Microsoft forecast the relative revenue growth rates of its Productivity & Business Processes, Intelligent Cloud, and More Personal Computing segments through FY2027, and what drivers underpin each segment’s outlook?
# 2. What is the expected trajectory of Microsoft’s operating cash‑flow conversion ratio over the next three fiscal years, and how does management plan to sustain or improve it?
# 3. Which subscription‑based ARR (annual recurring revenue) targets does Microsoft set for Azure, Microsoft 365, and Dynamics 365 for FY2026‑FY2028, and how will these targets affect overall earnings per share (EPS) growth?
# 4. How does Microsoft anticipate its gross margin to evolve as a percentage of revenue in light of anticipated cloud‑infrastructure cost structure and software licensing mix?
# 5. What are the projected capital expenditure priorities (e.g., data‑center expansion, AI hardware) through FY2026, and how will they influence the company’s free cash flow generation?
# 6. How does Microsoft expect its effective tax rate to change under upcoming global tax reforms, and what impact will this have on net income outlook and valuation multiples?
#
# **Industry & Competition (5)**
# 7. What market‑share gains or losses does Microsoft anticipate in the global cloud infrastructure market (IaaS/PaaS) versus key rivals (e.g., AWS, Google Cloud) through FY2027, and how will this affect Azure‑related revenue growth?
# 8. How does Microsoft expect the competitive dynamics of the enterprise software licensing market (e.g., Office, Teams) to evolve with the rise of low‑cost alternatives, and what pricing or bundling strategies are planned to defend market position?
# 9. In the AI‑augmented software ecosystem, what share of total AI‑driven revenue does Microsoft project for its own models versus third‑party integrations by FY2026, and how will this influence overall profit margins?
# 10. How will regulatory developments in data sovereignty and privacy (e.g., GDPR‑style laws) across major regions impact Microsoft’s ability to sell cross‑border cloud services, and what mitigation tactics are being deployed?
# 11. What is Microsoft’s outlook for the demand elasticity of its gaming and interactive entertainment segment (Xbox, Game Pass) in light of competing subscription platforms, and how could this affect segment earnings contribution?
#
# **Financial Performance (5)**
# 12. What EPS growth rate does management target for FY2025‑FY2028, and which line‑item drivers (e.g., licensing, cloud services, cost efficiencies) are expected to be the primary contributors?
# 13. How does Microsoft project its debt‑to‑EBITDA ratio to evolve with planned share repurchases and debt issuances, and what implications does this have for financial risk premiums priced into the stock?
# 14. What are the anticipated trends in Microsoft’s non‑GAAP operating income margin through FY2027, and how are investments in AI and cybersecurity expected to affect that margin?
# 15. How does Microsoft expect its dividend payout ratio to change over the next three years given projected cash flow generation and capital allocation priorities?
# 16. What is the forecasted impact of foreign‑exchange fluctuations on Microsoft’s consolidated revenue and net income for FY2026, and how does management intend to hedge this exposure?
#
# **Growth Drivers (4)**
# 17. What revenue contribution does Microsoft estimate from AI‑powered Copilot integrations across its productivity suite by FY2026, and how will this influence overall top‑line growth?
# 18. How does Microsoft anticipate the expansion of its Azure OpenAI Service to enterprise customers to affect the company's total cloud services ARR over the next five years?
# 19. What is the projected incremental revenue from Microsoft’s “cloud for verticals” strategy (e.g., healthcare, manufacturing) through FY2027, and what go‑to‑market initiatives are planned to capture it?
# 20. How will Microsoft’s strategic partnerships with hyperscale hardware vendors (e.g., NVIDIA, AMD) accelerate the adoption of its AI infrastructure offerings, and what measurable impact on revenue and margins is expected?
#
# **Operational Risks (3)**
# 21. What are the projected cost and timeline implications of Microsoft’s ongoing data‑center build‑out program in response to supply‑chain constraints, and how might delays affect cloud capacity growth?
# 22. How does Microsoft assess the risk of large‑scale cybersecurity incidents on its Azure and Microsoft 365 platforms, and what quantifiable financial reserves or insurance mechanisms are in place to mitigate potential earnings impact?
# 23. What is the expected effect of talent scarcity in AI and cloud engineering on Microsoft’s ability to meet product‑release milestones, and how are hiring and retention programs factored into operating expense forecasts?
#
# **Macroeconomic Factors (2)**
# 24. How does Microsoft model the sensitivity of its cloud services demand to global GDP growth and corporate IT‑spending cycles, and what scenarios are used to stress‑test revenue guidance?
# 25. In what ways could major shifts in interest‑rate policy influence Microsoft’s cost of capital and valuation multiples, and how does management incorporate these macro‑variables into its long‑term financial planning?
#
# **Management & Strategy (2)**
# 26. What strategic milestones does Microsoft’s senior leadership set for expanding its “intelligent edge” ecosystem (e.g., Azure Edge Zones, IoT) through FY2028, and how are these milestones tied to projected revenue streams?
# 27. How does Microsoft plan to allocate its R&D budget across AI, cloud, and quantum computing initiatives over the next three years, and what expected return on investment metrics are used to prioritize projects?
#
# **Valuation Drivers (2)**
# 28. Which forward‑looking multiples (e.g., EV/EBITDA, P/E) does management anticipate the market will apply to Microsoft’s cloud and AI businesses relative to historical averages, and what growth assumptions drive those multiples?
# 29. How does Microsoft expect changes in share‑repurchase volume and timing to affect its diluted EPS trajectory and the implied price‑to‑earnings valuation over the next five years?
#
# **Upcoming Catalysts (1)**
# 30. What are the key product launch dates and contractual win milestones (e.g., large enterprise cloud contracts, AI platform rollouts) scheduled for the next 12‑18 months that could materially shift analyst expectations and trigger stock price re‑rating?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Solventum.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How is Solventum’s projected product‑price elasticity expected to evolve as it expands into new therapeutic areas within the next 12‑24 months?
# 2. What proportion of total revenue is anticipated to be generated from recurring contracts or subscription‑based services versus one‑time sales over the next three years?
# 3. How does the company forecast changes in its gross margin profile as it scales production of its flagship biologic platform?
# 4. What are the expected impacts of upcoming CMS reimbursement policy adjustments on Solventum’s net‑to‑payer pricing strategy?
# 5. How will Solventum’s R&D budget allocation between early‑stage discovery and late‑stage clinical development shift in the 2025‑2027 horizon?
# 6. What is the anticipated timeline and capital requirement for commercial launch of the company’s pipeline asset targeting rare hematologic disorders?
#
# **Industry & Competition (5)**
# 7. How does Solventum expect its market share in the niche oncology segment to change relative to its top three competitors as new guideline‑driven therapies are adopted?
# 8. What competitive pressures are projected to arise from biosimilar entrants in Solventum’s core therapeutic categories, and how might these affect pricing power?
# 9. How will changes in FDA fast‑track designation criteria influence Solventum’s ability to expedite approval compared with peer firms?
# 10. What is the expected impact of emerging digital health platforms on patient adherence rates for Solventum’s chronic‑disease products?
# 11. How does the consolidation trend among large pharmaceutical distributors forecast to affect Solventum’s channel‑mix and distribution costs?
#
# **Financial Performance (5)**
# 12. What cash‑conversion cycle improvements does Solventum target to achieve by fiscal 2026, and how will these affect free‑cash‑flow generation?
# 13. How does the company plan to balance debt repayment with strategic reinvestment in its pipeline over the next three years?
# 14. What are the projected operating expense growth rates for SG&A versus R&D, and how will these ratios influence EBITDA margin trends?
# 15. How does Solventum anticipate changes in its effective tax rate, given anticipated international tax reforms, to impact net earnings per share?
# 16. What capital‑expenditure priorities are identified for expanding manufacturing capacity, and how will these expenditures be funded?
#
# **Growth Drivers (4)**
# 17. What regulatory milestones (e.g., Phase III readouts, FDA advisory committee meetings) are expected to drive revenue acceleration for Solventum’s lead assets in the next two years?
# 18. How will the planned entry into the European Union market affect total addressable market size and projected sales growth?
# 19. What strategic partnership or licensing opportunities is Solventum evaluating to broaden its product pipeline, and what revenue upside is modeled from such collaborations?
# 20. How does the company forecast the revenue impact of a potential acquisition of a complementary med‑tech firm within the next 18 months?
#
# **Operational Risks (3)**
# 21. What supply‑chain diversification measures is Solventum implementing to mitigate raw‑material shortages for its biologic manufacturing, and how might residual risks affect production timelines?
# 22. How does the company assess the likelihood of regulatory inspection findings at its CDMO facilities, and what contingency plans are in place to address potential disruptions?
# 23. What talent‑retention strategies are being deployed to maintain critical scientific expertise, and how could turnover rates affect R&D milestones?
#
# **Macroeconomic Factors (2)**
# 24. How are projected changes in U.S. healthcare spending growth rates expected to influence Solventum’s long‑term revenue trajectory?
# 25. What demographic shifts (e.g., aging population prevalence of chronic diseases) are factored into Solventum’s market‑size forecasts for its next‑generation therapies?
#
# **Management & Strategy (2)**
# 26. How does Solventum’s executive compensation structure align with achieving specific stock‑price performance targets over the next five years?
# 27. What strategic initiatives are being prioritized to enhance shareholder value beyond organic growth, and how are success metrics defined for these initiatives?
#
# **Valuation Drivers (2)**
# 28. How does Solventum anticipate its forward price‑to‑earnings multiple to evolve relative to the healthcare sector median as pipeline risk de‑risko progresses?
# 29. What discount rate assumptions are being applied in the company’s discounted‑cash‑flow valuation, and how sensitive is the intrinsic value to changes in WACC driven by interest‑rate outlooks?
#
# **Upcoming Catalysts (1)**
# 30. What are the expected market reactions and price‑impact scenarios surrounding the FDA’s scheduled decision on Solventum’s flagship gene‑therapy candidate in Q3 2025?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Ventas.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='gpt-oss-120b',
    input=prompt
)
print(result.output_text)
# Out:
# **Business Fundamentals (6)**
# 1. How does Ventas project the average weighted‑average lease term (AWALT) for its portfolio to evolve over the next three years, and what impact will that have on future cash‑flow stability?
# 2. What is the expected net operating income (NOI) growth rate for each core property segment (senior housing, life science, medical office, etc.) through FY2028, and how are those rates derived from pipeline activity and rent escalations?
# 3. How does Ventas anticipate the proportion of newly‑acquired versus organically‑grown assets to shift in its capital allocation plan, and what effect will that have on the REIT’s leverage profile?
# 4. What are management’s assumptions regarding future occupancy rates for each property type, and how will deviations from those assumptions influence the REIT’s effective gross income?
# 5. How does the company forecast the timing and magnitude of rent escalations tied to CPI versus market‑based lease renewals, and what sensitivity does the model have to inflation variance?
# 6. What is the expected contribution of ancillary services (e.g., equipment leasing, pharmacy services) to total revenue growth, and how will changes in those services affect overall margin expansion?
#
# **Industry & Competition (5)**
# 1. How does Ventas compare its projected average rent per square foot growth to the consensus forecasts for the broader U.S. health‑care REIT sector, and what market share changes are expected?
# 2. What are the anticipated effects of new entrant developments in the life‑science office market on Ventas’s lease‑rate positioning and tenant acquisition costs?
# 3. How does the competitive landscape for senior housing REITs influence Ventas’s pricing power, and what are the expected shifts in relative occupancy versus peers?
# 4. What level of consolidation activity (mergers, acquisitions, dispositions) does Ventas expect in the health‑care real‑estate space, and how could that reshape competitive dynamics and pricing?
# 5. How will changes in regulatory reimbursement rates for Medicare/Medicaid affect the relative attractiveness of Ventas’s tenant base compared with non‑health‑care REIT competitors?
#
# **Financial Performance (5)**
# 1. What is Ventas’s projected adjusted Funds From Operations (AFFO) growth trajectory over the next five years, and which line‑item drivers (rent growth, expense control, acquisitions) dominate the forecast?
# 2. How does management expect the REIT’s debt maturity schedule to evolve, and what impact will refinancing assumptions have on interest expense and net income margins?
# 3. What are the anticipated trends in property‑level capex versus capitalized improvements, and how will those capital allocation choices affect long‑term NOI and cash‑flow generation?
# 4. How does Ventas plan to manage its dividend payout ratio in relation to projected AFFO, and what scenarios could trigger a change in the payout policy?
# 5. What is the expected effective tax rate under current tax law reforms, and how will variations in that rate influence net earnings per share and valuation multiples?
#
# **Growth Drivers (4)**
# 1. What pipeline of new development projects (square footage, locations, target tenant mix) does Ventas anticipate completing by 2027, and how will those assets contribute to incremental revenue?
# 2. How does the company forecast the impact of demographic shifts (e.g., aging baby boomers) on demand for senior housing and associated rent growth across its portfolio?
# 3. What is the expected effect of expanding partnerships with integrated health‑systems on lease‑back arrangements and long‑term revenue stability?
# 4. How will advancements in tele‑health and outpatient care models influence Ventas’s strategy for acquiring or repurposing medical‑office properties, and what revenue uplift is projected?
#
# **Operational Risks (3)**
# 1. How does Ventas assess the probability and financial impact of tenant bankruptcies within its senior housing segment under different economic stress scenarios?
# 2. What contingency plans are in place for construction delays or cost overruns on development projects, and how would those affect projected cash‑flow timing?
# 3. How does management evaluate the risk of regulatory changes (e.g., licensure requirements for health‑care facilities) on occupancy and rent renewal terms, and what mitigation strategies are outlined?
#
# **Macroeconomic Factors (2)**
# 1. How does Ventas model the sensitivity of its AFFO to changes in the U.S. interest‑rate environment, particularly in the context of expected Fed policy cycles over the next 24 months?
# 2. What assumptions does the company make about regional employment growth and health‑care spending trends, and how will those macro variables drive demand for its property types?
#
# **Management & Strategy (2)**
# 1. How does the executive team prioritize capital deployment among acquisition, development, and share‑repurchase initiatives, and what performance metrics guide those decisions?
# 2. What is the strategic rationale behind Ventas’s target geographic expansion (e.g., Sun Belt markets), and how is projected market‑level rent growth incorporated into that plan?
#
# **Valuation Drivers (2)**
# 1. How does Ventas expect its price‑to‑AFFO multiple to respond to projected changes in the REIT’s credit rating and leverage ratios over the next three years?
# 2. What forward‑looking assumptions does management use for terminal value calculations in its discounted cash‑flow model, and how sensitive is the implied stock price to variations in those assumptions?
#
# **Upcoming Catalysts (1)**
# 1. What are the anticipated financial and operational impacts of Ventas’s next scheduled property disposition or large‑scale acquisition (including expected timing, size, and financing structure) on FY2025 earnings guidance?
