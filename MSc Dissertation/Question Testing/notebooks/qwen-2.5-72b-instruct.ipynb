# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Netflix.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals (6)
# 1. What new content categories is Netflix planning to explore in the next 12 months, and how do they align with current viewer trends?
# 2. How does Netflix plan to enhance its user experience through technology, such as AI and personalization, over the next two years?
# 3. What is the expected impact of recent price increases on subscriber growth and churn rates in key markets?
# 4. How does Netflix plan to leverage its original content to differentiate itself from competitors in the next 18 months?
# 5. What are the key metrics Netflix uses to measure the success of its marketing campaigns, and how have these metrics evolved over the past year?
# 6. How does Netflix plan to address the challenge of content localization in emerging markets?
#
# ### Industry & Competition (5)
# 7. What are the primary competitive threats to Netflix's market position in the next 24 months, and how is the company preparing to counter them?
# 8. How do changes in the regulatory environment, particularly around content distribution and data privacy, affect Netflix's business model?
# 9. What is the expected impact of new entrants in the streaming market on Netflix's subscriber base and revenue?
# 10. How does Netflix plan to maintain its leadership in content creation amidst increasing competition from other streaming services?
# 11. What strategic partnerships or acquisitions is Netflix considering to strengthen its market position?
#
# ### Financial Performance (5)
# 12. What is the projected revenue growth rate for Netflix over the next three years, and what factors will drive this growth?
# 13. How does Netflix plan to manage its debt levels and capital structure to support long-term growth?
# 14. What is the expected impact of foreign exchange rate fluctuations on Netflix's international revenue and profitability?
# 15. How does Netflix plan to optimize its cost structure to improve margins in the face of rising content production costs?
# 16. What is the expected return on investment (ROI) for Netflix's recent content spending, and how does it compare to previous periods?
#
# ### Growth Drivers (4)
# 17. What new geographic markets is Netflix targeting for expansion, and what strategies will it employ to succeed in these regions?
# 18. How does Netflix plan to leverage its brand to enter adjacent markets, such as gaming or live events?
# 19. What is the expected contribution of non-subscription revenue streams, such as advertising and merchandise, to Netflix's overall revenue in the next five years?
# 20. How does Netflix plan to capitalize on the growing trend of binge-watching and short-form content to attract younger viewers?
#
# ### Operational Risks (3)
# 21. What are the potential risks associated with Netflix's heavy reliance on third-party content providers, and how is the company mitigating these risks?
# 22. How does Netflix plan to address the challenge of content piracy and ensure the integrity of its streaming service?
# 23. What measures is Netflix taking to protect user data and comply with global data protection regulations?
#
# ### Macroeconomic Factors (2)
# 24. How will changes in consumer spending patterns, particularly during economic downturns, affect Netflix's subscriber growth and retention?
# 25. What is the expected impact of interest rate changes on Netflix's borrowing costs and financial flexibility?
#
# ### Management & Strategy (2)
# 26. What is the management team's vision for Netflix's long-term strategy, and how does it differ from current operations?
# 27. How does Netflix plan to foster innovation and maintain a culture of creativity within the organization?
#
# ### Valuation Drivers (2)
# 28. What is the expected impact of Netflix's expanding content library on its valuation multiples, and how does this compare to peers?
# 29. How does Netflix's current P/E ratio reflect investor sentiment, and what factors could cause it to converge with or diverge from industry averages?
#
# ### Upcoming Catalysts (1)
# 30. What are the key upcoming events, such as new content releases or strategic announcements, that could significantly impact Netflix's stock performance in the next six months?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Amazon.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals (6)
# 1. What new product categories does Amazon plan to introduce in the next 12 months, and how do they align with consumer trends?
# 2. How does Amazon intend to enhance its logistics network to improve delivery times and reduce costs over the next two years?
# 3. What are Amazon's plans for expanding its cloud computing services (AWS) into emerging markets, and what are the expected revenue contributions?
# 4. How will Amazon leverage artificial intelligence and machine learning to optimize its supply chain and customer experience in the next three years?
# 5. What strategies is Amazon implementing to increase its market share in the grocery and food delivery segment?
# 6. How does Amazon plan to address growing regulatory pressures, particularly in areas like antitrust and data privacy?
#
# ### Industry & Competition (5)
# 7. What are the key competitive threats to Amazon's e-commerce business from companies like Walmart, Target, and Shopify?
# 8. How does Amazon plan to maintain its leadership in the cloud computing market amidst increasing competition from Microsoft Azure and Google Cloud?
# 9. What are the potential impacts of new entrants in the smart home and IoT market on Amazon's device sales (e.g., Echo, Ring)?
# 10. How will changes in consumer spending habits post-pandemic affect Amazon's core e-commerce business?
# 11. What strategic partnerships is Amazon pursuing to strengthen its position in the consumer discretionary sector?
#
# ### Financial Performance (5)
# 12. What are the expected growth rates for Amazon's net sales and operating income over the next five years?
# 13. How will Amazon manage its capital expenditures to support expansion while maintaining healthy cash flow?
# 14. What are the primary drivers of Amazon's gross margin improvements, and how sustainable are these trends?
# 15. How does Amazon plan to allocate free cash flow to balance debt reduction, share buybacks, and investments in new ventures?
# 16. What are the projected returns on investment for Amazon's recent acquisitions and their impact on financial performance?
#
# ### Growth Drivers (4)
# 17. What new geographic markets is Amazon targeting for expansion, and what are the expected revenue contributions?
# 18. How will Amazon's subscription services (Prime, Amazon Music, etc.) evolve to attract and retain more customers?
# 19. What role will sustainability initiatives play in driving long-term growth and brand loyalty?
# 20. How does Amazon plan to capitalize on the growing trend of online advertising and what are the expected revenue impacts?
#
# ### Operational Risks (3)
# 21. What are the potential risks associated with Amazon's reliance on third-party sellers, and how is the company mitigating these risks?
# 22. How will labor shortages and rising wages affect Amazon's operational efficiency and cost structure?
# 23. What measures is Amazon taking to ensure supply chain resilience in the face of global disruptions?
#
# ### Macroeconomic Factors (2)
# 24. How will changes in interest rates and inflation impact Amazon's borrowing costs and consumer spending patterns?
# 25. What are the potential effects of geopolitical tensions and trade policies on Amazon's international operations?
#
# ### Management & Strategy (2)
# 26. How will the new leadership under CEO Andy Jassy shape Amazon's strategic direction and priorities?
# 27. What is Amazon's approach to balancing short-term profits with long-term investments in innovation and growth?
#
# ### Valuation Drivers (2)
# 28. What are the key valuation multiples that investors should consider when assessing Amazon's stock, and how do they compare to industry peers?
# 29. How do analysts expect Amazon's earnings per share (EPS) to grow over the next five years, and what factors will drive this growth?
#
# ### Upcoming Catalysts (1)
# 30. What are the most significant upcoming events or announcements (e.g., product launches, regulatory decisions) that could impact Amazon's stock price in the near term?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Amcor.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals (6)
# 1. What new product innovations does Amcor plan to introduce in the next 12-24 months, and how will they impact market share?
# 2. How does Amcor's customer diversification strategy mitigate risks associated with reliance on key clients?
# 3. What are Amcor's plans for expanding into emerging markets, and what are the expected returns on these investments?
# 4. How does Amcor's sustainability and environmental responsibility initiatives align with consumer trends and regulatory requirements?
# 5. What is the current status of Amcor's digital transformation efforts, and how will they enhance operational efficiency?
# 6. How does Amcor's supply chain management strategy ensure resilience against global disruptions?
#
# ### Industry & Competition (5)
# 7. What are the key trends in the materials industry that could affect Amcor's market position over the next five years?
# 8. How do Amcor's competitors' pricing strategies compare, and what impact do they have on Amcor's profitability?
# 9. What technological advancements in packaging materials are expected to disrupt the industry, and how is Amcor preparing for them?
# 10. How does Amcor's R&D investment compare to its competitors, and what specific areas are being prioritized?
# 11. What are the barriers to entry in the materials industry, and how do they protect Amcor's market share?
#
# ### Financial Performance (5)
# 12. What are the projected revenue growth rates for Amcor's key business segments over the next three years?
# 13. How does Amcor plan to manage its debt levels and improve its credit rating in the coming years?
# 14. What is the expected impact of currency fluctuations on Amcor's international operations and financial performance?
# 15. How does Amcor's capital expenditure plan support long-term growth and profitability?
# 16. What are the key cost-saving measures Amcor is implementing to maintain margins amidst rising input costs?
#
# ### Growth Drivers (4)
# 17. What are the primary drivers of demand for Amcor's products in the consumer goods and pharmaceutical sectors?
# 18. How does Amcor's focus on sustainable packaging solutions align with growing consumer and regulatory demands?
# 19. What strategic partnerships or acquisitions does Amcor plan to pursue to expand its market presence?
# 20. How is Amcor leveraging e-commerce and digital marketing to reach new customers and increase brand awareness?
#
# ### Operational Risks (3)
# 21. What are the major operational risks Amcor faces in its global supply chain, and how are they being mitigated?
# 22. How does Amcor's workforce management strategy address labor shortages and skill gaps?
# 23. What are the potential impacts of regulatory changes on Amcor's operations and compliance costs?
#
# ### Macroeconomic Factors (2)
# 24. How will changes in global trade policies and tariffs affect Amcor's international business?
# 25. What is the expected impact of inflation on Amcor's raw material costs and pricing power?
#
# ### Management & Strategy (2)
# 26. What is the management team's vision for Amcor's long-term strategic direction, and how does it align with shareholder interests?
# 27. How does Amcor's corporate governance structure ensure transparency and accountability?
#
# ### Valuation Drivers (2)
# 28. What are the key valuation multiples used to assess Amcor's stock, and how do they compare to industry peers?
# 29. How does Amcor's dividend policy support shareholder value, and what changes are expected in the near term?
#
# ### Upcoming Catalysts (1)
# 30. What are the most significant upcoming events or announcements that could positively or negatively impact Amcor's stock price?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_AmEx.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals (6)
# 1. What new product or service offerings does American Express plan to introduce in the next 12 months, and how do they align with current market trends?
# 2. How does American Express intend to expand its merchant network, particularly in emerging markets, over the next two years?
# 3. What is the projected growth rate of the company's cardmember base over the next five years, and what strategies are in place to achieve this?
# 4. How does American Express plan to leverage digital technologies to enhance customer engagement and retention?
# 5. What is the expected impact of regulatory changes on American Express's core business operations in the next three years?
# 6. How does American Express plan to address the growing competition from fintech companies and digital payment platforms?
#
# ### Industry & Competition (5)
# 7. What are the key trends in the global payments industry that could impact American Express's market position in the next five years?
# 8. How do American Express's loyalty programs and rewards systems compare to those of its main competitors, and what improvements are planned?
# 9. What is the competitive landscape of the commercial card market, and how does American Express plan to maintain or increase its market share?
# 10. How does the rise of mobile payments and contactless transactions affect American Express's business model, and what strategies are being developed to adapt?
# 11. What are the potential threats from new entrants in the financial services sector, and how is American Express preparing to counter these?
#
# ### Financial Performance (5)
# 12. What is the forecasted revenue growth rate for American Express over the next three years, and what factors are driving this projection?
# 13. How does American Express plan to improve its net interest margin (NIM) in the face of changing interest rates?
# 14. What is the expected trend in the company's operating expenses over the next five years, and what cost-saving measures are being implemented?
# 15. How will changes in credit loss provisions affect American Express's profitability in the coming quarters?
# 16. What is the projected return on equity (ROE) for American Express over the next three years, and what factors will influence this metric?
#
# ### Growth Drivers (4)
# 17. What is the strategic importance of expanding into new geographic markets, and which regions are prioritized for growth?
# 18. How does American Express plan to capitalize on the increasing demand for travel and hospitality services post-pandemic?
# 19. What role will partnerships with other financial institutions and technology companies play in driving growth for American Express?
# 20. How does American Express plan to integrate artificial intelligence and machine learning into its operations to drive efficiency and innovation?
#
# ### Operational Risks (3)
# 21. What are the primary operational risks facing American Express, and how are they being mitigated?
# 22. How does American Express manage the risk of data breaches and cybersecurity threats, and what investments are planned in this area?
# 23. What is the impact of geopolitical tensions and trade policies on American Express's international operations, and how is the company addressing these risks?
#
# ### Macroeconomic Factors (2)
# 24. How will changes in global interest rates affect American Express's lending and borrowing activities?
# 25. What is the expected impact of inflation on American Express's operating costs and consumer spending patterns?
#
# ### Management & Strategy (2)
# 26. What is the long-term strategic vision of American Express's leadership team, and how does it align with shareholder interests?
# 27. How does American Express plan to balance short-term performance goals with long-term sustainability initiatives?
#
# ### Valuation Drivers (2)
# 28. What is the expected impact of share buybacks and dividend payouts on American Express's stock price in the next year?
# 29. How does American Express's valuation compare to its peers, and what factors could cause a revaluation in the near term?
#
# ### Upcoming Catalysts (1)
# 30. What are the key upcoming events or catalysts that could significantly impact American Express's stock performance in the next six months?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Costco.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals
# 1. What new initiatives is Costco planning to implement to enhance its private label brand offerings and increase their market share?
# 2. How does Costco plan to expand its e-commerce capabilities and online presence in the next three years?
# 3. What strategies is Costco employing to improve customer loyalty and retention rates?
# 4. How does Costco plan to address rising labor costs and maintain operational efficiency?
# 5. What are the key areas of investment for Costco in terms of technology and supply chain optimization?
# 6. How does Costco plan to leverage its membership model to drive higher revenue per member?
#
# ### Industry & Competition
# 7. What trends in the consumer staples industry are expected to impact Costco's competitive position in the next five years?
# 8. How do Costco's competitors (e.g., Walmart, Target) plan to challenge its market dominance, and what strategies is Costco implementing to counter these threats?
# 9. What are the potential impacts of increasing online competition from e-commerce giants like Amazon on Costco's business model?
# 10. How does Costco plan to differentiate itself in the growing market for organic and sustainable products?
# 11. What regulatory changes in the retail sector could affect Costco's operations and profitability?
#
# ### Financial Performance
# 12. What is the projected growth rate for Costco's gross margins over the next three years, and what factors will drive this change?
# 13. How does Costco plan to manage its capital expenditures to support expansion while maintaining healthy cash flow?
# 14. What is the expected trend in Costco's operating expenses as a percentage of sales over the next five years?
# 15. How will changes in inventory management practices impact Costco's working capital and financial performance?
# 16. What is the forecasted return on invested capital (ROIC) for Costco over the next three years?
#
# ### Growth Drivers
# 17. What are the key markets for Costco's international expansion, and what strategies are being implemented to succeed in these regions?
# 18. How does Costco plan to capitalize on the growing demand for health and wellness products in its stores?
# 19. What new product categories or services is Costco considering adding to its offerings to drive additional revenue streams?
# 20. How does Costco plan to leverage data analytics and customer insights to inform product selection and store layouts?
#
# ### Operational Risks
# 21. What are the primary supply chain risks facing Costco, and how is the company preparing to mitigate these risks?
# 22. How does Costco plan to address the potential impact of global trade tensions and tariffs on its cost structure?
# 23. What steps is Costco taking to ensure compliance with environmental regulations and reduce its carbon footprint?
#
# ### Macroeconomic Factors
# 24. How will changes in consumer spending patterns, particularly in discretionary spending, affect Costco's sales and profit margins?
# 25. What is the expected impact of inflation on Costco's pricing strategy and customer affordability?
#
# ### Management & Strategy
# 26. How does Costco's leadership plan to balance short-term financial goals with long-term strategic objectives?
# 27. What is the company's approach to corporate governance and how does it align with shareholder interests?
#
# ### Valuation Drivers
# 28. What is the projected earnings growth rate for Costco over the next five years, and how will this impact its valuation multiples?
# 29. How does the current market valuation of Costco compare to its peers, and what factors could lead to revaluation?
#
# ### Upcoming Catalysts
# 30. What significant events or announcements (e.g., new store openings, major partnerships) are expected to drive investor sentiment and stock performance in the near term?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Halliburton.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals
# 1. What new technologies or services is Halliburton planning to introduce in the next 12 months that could significantly impact its market share?
# 2. How does Halliburton plan to address the growing demand for sustainable and environmentally friendly drilling solutions?
# 3. What is Halliburton's strategy for expanding its international operations, particularly in emerging markets?
# 4. How is Halliburton leveraging digital transformation and automation to improve operational efficiency and reduce costs?
# 5. What percentage of Halliburton's revenue is expected to come from unconventional resources (e.g., shale, tight oil) in the next three years?
# 6. How is Halliburton positioning itself to benefit from the transition to cleaner energy sources, such as natural gas and renewable energy integration?
#
# ### Industry & Competition
# 7. What are the key trends in the global energy sector that could affect Halliburton's business model over the next five years?
# 8. How do Halliburton's service offerings compare to those of its main competitors, and what are the key differentiators?
# 9. What is the current market share of Halliburton in the North American and international markets, and how is it expected to change in the next two years?
# 10. How are regulatory changes, particularly those related to environmental standards, likely to impact Halliburton's operations and costs?
# 11. What are the major challenges Halliburton faces from new entrants in the market, especially those focusing on innovative technologies?
#
# ### Financial Performance
# 12. What is the projected growth rate of Halliburton's EBITDA over the next three years, and what factors will drive this growth?
# 13. How does Halliburton plan to manage its debt levels and improve its credit ratings in the coming years?
# 14. What is the expected return on invested capital (ROIC) for Halliburton over the next five years, and how does this compare to industry averages?
# 15. How will changes in commodity prices (oil, natural gas) impact Halliburton's revenue and profitability in the short and long term?
# 16. What is the forecasted free cash flow for Halliburton over the next three years, and how will it be allocated?
#
# ### Growth Drivers
# 17. What new markets or segments is Halliburton targeting for expansion, and what strategies are being employed to achieve this?
# 18. How is Halliburton investing in research and development to maintain a competitive edge in technology and innovation?
# 19. What partnerships or collaborations is Halliburton pursuing to enhance its service offerings and market presence?
# 20. How will Halliburton leverage its existing customer relationships to drive additional revenue streams?
#
# ### Operational Risks
# 21. What are the primary operational risks Halliburton faces, and what measures are in place to mitigate these risks?
# 22. How is Halliburton preparing for potential supply chain disruptions, especially in critical components and materials?
# 23. What is the impact of geopolitical tensions on Halliburton's international operations, and how is the company addressing these issues?
#
# ### Macroeconomic Factors
# 24. How will changes in global interest rates and inflation affect Halliburton's cost structure and capital expenditure plans?
# 25. What is the expected impact of macroeconomic conditions, such as GDP growth and industrial production, on Halliburton's demand for services?
#
# ### Management & Strategy
# 26. What is the management team's vision for Halliburton's long-term strategic direction, and how does it align with industry trends?
# 27. How is Halliburton's leadership planning to balance short-term performance with long-term sustainability goals?
#
# ### Valuation Drivers
# 28. What is the expected price-to-earnings (P/E) ratio for Halliburton over the next three years, and what factors will influence this valuation?
# 29. How does Halliburton's dividend policy and share repurchase program support shareholder value creation?
#
# ### Upcoming Catalysts
# 30. What are the key upcoming events or announcements (e.g., new project launches, regulatory decisions) that could significantly impact Halliburton's stock performance in the near term?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Honeywell.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals (6)
# 1. What new products or services does Honeywell plan to introduce in the next 12 months, and what is the expected market impact?
# 2. How does Honeywell plan to enhance its smart building solutions to stay ahead of competitors in the IoT and automation space?
# 3. What are Honeywell's key strategies for expanding its presence in emerging markets, particularly in Asia-Pacific and Latin America?
# 4. How is Honeywell leveraging artificial intelligence and machine learning to improve operational efficiency and product development?
# 5. What are the primary customer segments Honeywell targets, and how is the company addressing their evolving needs?
# 6. How does Honeywell plan to integrate sustainability into its core business operations and product offerings?
#
# ### Industry & Competition (5)
# 7. What are the major trends in the industrial automation and control systems market, and how is Honeywell positioning itself to capitalize on these trends?
# 8. How does Honeywell's market share in key segments like aerospace, building technologies, and safety and productivity solutions compare to its main competitors?
# 9. What are the barriers to entry for new players in the industrial technology sector, and how does Honeywell maintain its competitive edge?
# 10. How is the increasing focus on environmental regulations and sustainability affecting the industrial sector, and what steps is Honeywell taking to comply and innovate?
# 11. What is the impact of global supply chain disruptions on Honeywell's ability to meet customer demand and maintain profitability?
#
# ### Financial Performance (5)
# 12. What are Honeywell's projections for revenue growth over the next three years, and what factors are driving this growth?
# 13. How does Honeywell plan to manage its capital expenditures to support expansion while maintaining financial stability?
# 14. What is the expected impact of currency fluctuations on Honeywell's international operations and financial performance?
# 15. How does Honeywell plan to optimize its cost structure to improve operating margins in the face of rising input costs?
# 16. What is the current debt-to-equity ratio, and what is Honeywell's strategy for managing its balance sheet to ensure long-term financial health?
#
# ### Growth Drivers (4)
# 17. What are the key geographic regions where Honeywell sees the most significant growth opportunities, and what strategies are being implemented to capture these markets?
# 18. How is Honeywell leveraging its existing technology and expertise to enter new markets or expand its product portfolio?
# 19. What partnerships or collaborations is Honeywell pursuing to drive innovation and growth in areas like digital transformation and sustainability?
# 20. How does Honeywell plan to leverage its strong brand reputation to gain a competitive advantage in new and existing markets?
#
# ### Operational Risks (3)
# 21. What are the primary operational risks Honeywell faces, and what measures are in place to mitigate these risks?
# 22. How is Honeywell preparing for potential disruptions in its supply chain, such as geopolitical tensions or natural disasters?
# 23. What is the impact of regulatory changes, particularly in environmental and safety standards, on Honeywell's operations and compliance costs?
#
# ### Macroeconomic Factors (2)
# 24. How will changes in interest rates and inflation affect Honeywell's borrowing costs and consumer spending patterns?
# 25. What is the expected impact of global economic conditions, such as trade policies and economic growth rates, on Honeywell's international sales and profitability?
#
# ### Management & Strategy (2)
# 26. What is Honeywell's long-term strategic vision, and how does it align with the company's mission and values?
# 27. How does Honeywell's leadership team plan to foster a culture of innovation and continuous improvement within the organization?
#
# ### Valuation Drivers (2)
# 28. What are the key valuation metrics that investors should focus on when assessing Honeywell's stock, and how do they compare to industry peers?
# 29. How does Honeywell's dividend policy and share repurchase program contribute to shareholder value?
#
# ### Upcoming Catalysts (1)
# 30. What are the most significant upcoming events or catalysts that could positively or negatively impact Honeywell's stock price in the next 12 months?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Microsoft.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals
# 1. What new products or services is Microsoft planning to launch in the next 12 months that could significantly impact its revenue?
# 2. How does Microsoft plan to enhance its cloud computing offerings to maintain its competitive edge over AWS and Google Cloud?
# 3. What are the key areas of investment for Microsoft in AI and machine learning, and how do they align with the company's long-term growth strategy?
# 4. How is Microsoft addressing the growing demand for hybrid work solutions, and what specific initiatives are being developed?
# 5. What are the strategic priorities for Microsoft's gaming division, particularly with the integration of Xbox and other gaming platforms?
# 6. How does Microsoft plan to leverage its partnership with OpenAI to expand its presence in the enterprise AI market?
#
# ### Industry & Competition
# 7. What are the primary trends in the IT industry that could affect Microsoft's market position in the next 5 years?
# 8. How does Microsoft plan to respond to increased competition from cloud providers like AWS and Google Cloud?
# 9. What are the potential threats from emerging technologies, such as quantum computing, to Microsoft's current business model?
# 10. How is the shift towards open-source software impacting Microsoft's software licensing business?
# 11. What are the key regulatory challenges facing Microsoft in the global market, and how does the company plan to address them?
#
# ### Financial Performance
# 12. What are the expected growth rates for Microsoft's key revenue segments (e.g., Productivity and Business Processes, Intelligent Cloud, More Personal Computing) over the next three years?
# 13. How does Microsoft plan to manage its operating expenses to maintain profitability amidst increasing investments in R&D and new ventures?
# 14. What is the forecasted EBITDA margin for Microsoft over the next two years, and what factors will drive this trend?
# 15. How will changes in tax laws and regulations globally impact Microsoft's effective tax rate and overall financial performance?
# 16. What is the expected cash flow from operations for Microsoft over the next five years, and how will it be allocated?
#
# ### Growth Drivers
# 17. How is Microsoft leveraging its Azure platform to capture more enterprise customers, and what specific strategies are being employed?
# 18. What role will Microsoft's acquisition strategy play in driving future growth, and what types of companies are likely targets?
# 19. How does Microsoft plan to expand its international presence, particularly in emerging markets?
# 20. What are the key initiatives for Microsoft to drive adoption of its Windows 11 operating system and related ecosystem?
#
# ### Operational Risks
# 21. What are the major cybersecurity risks facing Microsoft, and how is the company preparing to mitigate these threats?
# 22. How does Microsoft plan to address supply chain disruptions and ensure the availability of critical components for its hardware products?
# 23. What are the potential impacts of labor shortages or talent retention issues on Microsoft's ability to innovate and deliver new products?
#
# ### Macroeconomic Factors
# 24. How will changes in interest rates and inflation impact Microsoft's capital structure and cost of capital?
# 25. What are the potential effects of global economic downturns on Microsoft's revenue streams, particularly in enterprise software and cloud services?
#
# ### Management & Strategy
# 26. What are the key strategic initiatives outlined by Microsoft's leadership team for the next fiscal year, and how do they align with the company's long-term goals?
# 27. How does Microsoft plan to balance short-term financial performance with long-term strategic investments?
#
# ### Valuation Drivers
# 28. What is the expected impact of Microsoft's share buyback program on its stock price over the next 12 months?
# 29. How do changes in multiples (P/E, EV/EBITDA) for the IT sector affect the valuation of Microsoft's stock?
#
# ### Upcoming Catalysts
# 30. What are the most significant upcoming events or announcements (e.g., product launches, regulatory decisions, M&A activities) that could catalyze a change in Microsoft's stock price?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Solventum.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals (6)
# 1. What new healthcare products or services is Solventum planning to launch in the next 12 months, and what is the expected market size for these offerings?
# 2. How does Solventum plan to expand its customer base in the next two years, particularly in emerging markets?
# 3. What is the company's strategy for integrating recent acquisitions into its existing operations, and what synergies are expected?
# 4. How does Solventum plan to leverage technology (e.g., AI, telemedicine) to enhance its product offerings and operational efficiency?
# 5. What is the current R&D pipeline, and which projects have the highest potential for commercial success?
# 6. How does Solventum plan to address the increasing regulatory scrutiny in the healthcare industry?
#
# ### Industry & Competition (5)
# 7. What are the key trends in the healthcare industry that could impact Solventum's business model over the next five years?
# 8. How does Solventum's market share compare to its top three competitors, and what strategies is it employing to gain or maintain its position?
# 9. What are the barriers to entry in Solventum's primary markets, and how do they affect the company's competitive advantage?
# 10. How is the shift towards value-based care affecting Solventum's business, and what steps is the company taking to adapt?
# 11. What is the level of consolidation in the healthcare industry, and how might this impact Solventum's strategic decisions?
#
# ### Financial Performance (5)
# 12. What is the projected revenue growth rate for Solventum over the next three years, and what factors are driving this growth?
# 13. How has Solventum's gross margin trended over the past three years, and what changes are expected in the near term?
# 14. What is the company's capital expenditure plan for the next fiscal year, and how will these investments contribute to long-term profitability?
# 15. How does Solventum manage its working capital, and what improvements are planned to optimize cash flow?
# 16. What is the expected impact of any pending legal or regulatory issues on Solventum's financial performance?
#
# ### Growth Drivers (4)
# 17. What are the key geographic regions where Solventum plans to expand, and what are the growth opportunities in these markets?
# 18. How does Solventum plan to capitalize on the growing demand for personalized medicine and genetic testing?
# 19. What partnerships or collaborations is Solventum pursuing to drive innovation and market expansion?
# 20. How does the company plan to leverage its existing brand and reputation to enter new product categories or markets?
#
# ### Operational Risks (3)
# 21. What are the major supply chain risks facing Solventum, and what measures are in place to mitigate these risks?
# 22. How does Solventum plan to address the potential shortage of skilled healthcare professionals, and what training programs are being developed?
# 23. What is the company's strategy for managing cybersecurity threats and protecting patient data?
#
# ### Macroeconomic Factors (2)
# 24. How sensitive is Solventum's revenue to changes in interest rates, and what hedging strategies are in place?
# 25. What is the impact of global economic conditions on Solventum's international operations, and how is the company preparing for potential downturns?
#
# ### Management & Strategy (2)
# 26. What is the management team's vision for Solventum's long-term growth, and how does this align with shareholder interests?
# 27. How does Solventum's board of directors ensure effective corporate governance and oversight of strategic initiatives?
#
# ### Valuation Drivers (2)
# 28. What is the expected return on invested capital (ROIC) for Solventum over the next five years, and how does this compare to industry peers?
# 29. How does Solventum's dividend policy support its overall financial strategy, and what changes are anticipated in the near term?
#
# ### Upcoming Catalysts (1)
# 30. What are the key upcoming events (e.g., product launches, regulatory approvals, M&A) that could significantly impact Solventum's stock price in the next 12 months?

# %%
import os
from openai import OpenAI
BASE_URL = "http://api.llm.apps.os.dcs.gla.ac.uk/v1"  # outside UofG network: "http://api.terrier.org/v1"
API_KEY = os.environ['IDA_LLM_API_KEY']
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)
with open('prompts/prompt_Ventas.txt', 'r', encoding='utf-8') as f:
    prompt = f.read()
result = client.responses.create(
    model='qwen-2.5-72b-instruct',
    input=prompt
)
print(result.output_text)
# Out:
# ### Business Fundamentals (6)
# 1. What new real estate investments does Ventas plan to make in the next 12 months, and how will these impact the company's portfolio diversification?
# 2. How does Ventas intend to optimize its existing healthcare and senior living properties to enhance occupancy rates and rental income?
# 3. What are the key strategies Ventas is implementing to improve tenant retention and reduce vacancy rates?
# 4. How does Ventas plan to leverage technology to enhance operational efficiency and resident experience in its properties?
# 5. What is Ventas' strategy for expanding into new geographic markets, and what are the expected returns on these investments?
# 6. How does Ventas plan to address the aging infrastructure of some of its older properties to maintain their value and appeal?
#
# ### Industry & Competition (5)
# 7. How does Ventas' market share in the senior living and healthcare real estate sectors compare to its main competitors, and what strategies are being employed to increase this share?
# 8. What are the key trends in the senior living and healthcare real estate markets that could impact Ventas' future performance?
# 9. How do regulatory changes in the healthcare sector, such as Medicare and Medicaid policies, affect Ventas' business model and profitability?
# 10. What are the competitive dynamics in the regions where Ventas operates, and how do they influence the company's strategic decisions?
# 11. How does Ventas differentiate itself from competitors in terms of property management, tenant relationships, and investment selection?
#
# ### Financial Performance (5)
# 12. What are the projected revenue growth rates for Ventas over the next three years, and what factors are driving this growth?
# 13. How does Ventas plan to manage its debt levels and interest expenses to maintain a strong balance sheet?
# 14. What is the expected impact of recent acquisitions on Ventas' financial performance, and how will they contribute to long-term growth?
# 15. How does Ventas' dividend policy align with its capital allocation strategy, and what are the expectations for future dividend increases?
# 16. What are the key metrics Ventas uses to measure financial health, and how do these metrics compare to industry benchmarks?
#
# ### Growth Drivers (4)
# 17. What new development projects does Ventas have in the pipeline, and what are the expected returns on these investments?
# 18. How does Ventas plan to capitalize on demographic trends, such as the aging population, to drive growth in its senior living and healthcare properties?
# 19. What partnerships or joint ventures is Ventas pursuing to expand its portfolio and enter new markets?
# 20. How does Ventas plan to integrate sustainability and green building practices into its properties to attract environmentally conscious tenants and investors?
#
# ### Operational Risks (3)
# 21. What are the potential risks associated with Ventas' reliance on specific types of properties, such as skilled nursing facilities, and how are these risks being mitigated?
# 22. How does Ventas plan to address the challenges of rising labor costs and regulatory compliance in the healthcare and senior living sectors?
# 23. What measures is Ventas taking to ensure the resilience of its properties against natural disasters and other physical risks?
#
# ### Macroeconomic Factors (2)
# 24. How sensitive is Ventas' revenue to changes in interest rates, and what strategies are in place to mitigate this risk?
# 25. What is the impact of economic recessions on the demand for senior living and healthcare properties, and how does Ventas prepare for such scenarios?
#
# ### Management & Strategy (2)
# 26. What is the management team's vision for Ventas' long-term growth, and how does it align with shareholder interests?
# 27. How does Ventas' board of directors ensure effective oversight and governance, particularly in areas such as risk management and strategic planning?
#
# ### Valuation Drivers (2)
# 28. What is the current price-to-earnings (P/E) ratio for Ventas, and how does it compare to industry peers?
# 29. What are the key factors that drive the valuation multiples for Ventas, and how are these factors expected to evolve in the coming years?
#
# ### Upcoming Catalysts (1)
# 30. What are the key upcoming events or announcements that could significantly impact Ventas' stock performance, such as new property acquisitions, regulatory changes, or strategic initiatives?
